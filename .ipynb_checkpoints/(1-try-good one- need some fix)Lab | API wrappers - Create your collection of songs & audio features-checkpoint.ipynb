# %% [markdown]
# ## Tell me a song,
# ## I will tell you if it is hot,
# ## if not I will recomend you a similar song.
#
# ![Pokemon](images/spotify.png)

# %%
check()

# %%
#Link of an exaple play list (with 13 songs it takes like 15 mins to run it).
'https://open.spotify.com/playlist/5XbnEtKOWl1c2GwfY1bnN8?si=03577c741a7f4de0'
# Out:
# 'https://open.spotify.com/playlist/5XbnEtKOWl1c2GwfY1bnN8?si=03577c741a7f4de0'

# %%
#Link of an exaple list, with 8 playlist, Melissa
'https://open.spotify.com/playlist/1FdJLnDlwpXfxBQGXY2En4?si=140c148d08d94402'
# Out:
# 'https://open.spotify.com/playlist/1FdJLnDlwpXfxBQGXY2En4?si=140c148d08d94402'

# %% [markdown]
# # Fixing the problem

# %%
#Importing the libraries.
import pandas as pd
from bs4 import BeautifulSoup
import requests
import random
import re
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
#Spotify credentials.
secrets_file = open("../../projects/spotify_user.txt","r")
string = secrets_file.read()
string.split('\n')
secrets_dict={}
for line in string.split('\n'):
  secrets_dict[line.split(':')[0]]=line.split(':')[1]

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['client_id'],
                                                           client_secret=secrets_dict['client_secret']))

# %%
def get_name_artists_from_track(track):
    return [(track["name"],track['artists'][0]['name'])]

def get_name_artist_from_playlist_item(playlist_item):
      return get_name_artists_from_track(playlist_item['track'])
    
def flatten(input_list):
      return [item for sublist in input_list for item in sublist]
    
def get_name_artists_from_playlist(input_playlist):
      return flatten(list(map(get_name_artist_from_playlist_item,input_playlist["items"])))

# %%
playlist = sp.user_playlist_tracks("spotify",'1FdJLnDlwpXfxBQGXY2En4')
get_name_artists_from_playlist(playlist)
# Out:
# [('Calentón', 'Daddy Yankee'),
#  ('Sola (Remix) [feat. Daddy Yankee, Wisin, Farruko, Zion & Lennox]',
#   'Anuel AA'),
#  ('Bye Bye Macadam', 'Rone'),
#  ('Hooka', 'Don Omar'),
#  ('Mundian To Bach Ke', 'Panjabi MC'),
#  ('Glasgow', 'David Guetta'),
#  ('Fiebre (Prod. King DouDou)', 'Bad Gyal'),
#  ('Antidote - Extended', 'Swedish House Mafia')]

# %%
songs = get_name_artists_from_playlist(playlist)

# %%
singers = []
for i in range(len(songs)):             
    singers.append(songs[i][1])

# %%
singers = list(dict.fromkeys(singers))

# %%
more_songs = []   
for i in range(len(singers)):  
      more_songs.append(get_artist_tracks(singers[i]))

# %%
more_songs = flatten(more_songs)

# %%
    songs_names = []
    artists_names = []
    uris = []

    # To have the songs and artists names and features
    for track in more_songs:
        songs_names.append(track['name'])
        artists_names.append(track['artists'][0]['name'])

    i = 0
    chunk_of_100_uris = []
    for track in more_songs:
        if i < 100:
            chunk_of_100_uris.append(sp.audio_features(track['uri']))
            i = i+1
        else:
            uris.append(chunk_of_100_uris)
            i = 0
            chunk_of_100_uris = []
            chunk_of_100_uris.append(sp.audio_features(track['uri']))
            i = i+1       
    uris.append(chunk_of_100_uris)

# %%
 uris = flatten(flatten(uris))

# %%
uris
# Out:
# [{'danceability': 0.744,
#   'energy': 0.868,
#   'key': 1,
#   'loudness': -4.524,
#   'mode': 1,
#   'speechiness': 0.047,
#   'acousticness': 0.0326,
#   'instrumentalness': 0,
#   'liveness': 0.0822,
#   'valence': 0.586,
#   'tempo': 93.037,
#   'type': 'audio_features',
#   'id': '69vlMrzHwATKzupwNcUPyK',
#   'uri': 'spotify:track:69vlMrzHwATKzupwNcUPyK',
#   'track_href': 'https://api.spotify.com/v1/tracks/69vlMrzHwATKzupwNcUPyK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/69vlMrzHwATKzupwNcUPyK',
#   'duration_ms': 206420,
#   'time_signature': 4},
#  {'danceability': 0.803,
#   'energy': 0.798,
#   'key': 6,
#   'loudness': -4.855,
#   'mode': 0,
#   'speechiness': 0.173,
#   'acousticness': 0.0764,
#   'instrumentalness': 0,
#   'liveness': 0.0775,
#   'valence': 0.761,
#   'tempo': 88.018,
#   'type': 'audio_features',
#   'id': '7ovjKFvnT8I9P0137MwSso',
#   'uri': 'spotify:track:7ovjKFvnT8I9P0137MwSso',
#   'track_href': 'https://api.spotify.com/v1/tracks/7ovjKFvnT8I9P0137MwSso',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7ovjKFvnT8I9P0137MwSso',
#   'duration_ms': 190440,
#   'time_signature': 4},
#  {'danceability': 0.793,
#   'energy': 0.771,
#   'key': 5,
#   'loudness': -3.417,
#   'mode': 1,
#   'speechiness': 0.0959,
#   'acousticness': 0.0337,
#   'instrumentalness': 1.51e-06,
#   'liveness': 0.284,
#   'valence': 0.835,
#   'tempo': 171.943,
#   'type': 'audio_features',
#   'id': '35UUpTmrcFXNIVIN26ujXl',
#   'uri': 'spotify:track:35UUpTmrcFXNIVIN26ujXl',
#   'track_href': 'https://api.spotify.com/v1/tracks/35UUpTmrcFXNIVIN26ujXl',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/35UUpTmrcFXNIVIN26ujXl',
#   'duration_ms': 247308,
#   'time_signature': 4},
#  {'danceability': 0.655,
#   'energy': 0.879,
#   'key': 0,
#   'loudness': -4.743,
#   'mode': 1,
#   'speechiness': 0.235,
#   'acousticness': 0.0321,
#   'instrumentalness': 6.97e-06,
#   'liveness': 0.0679,
#   'valence': 0.657,
#   'tempo': 184.027,
#   'type': 'audio_features',
#   'id': '5IPMTA3OFfgMVWVbDs5rls',
#   'uri': 'spotify:track:5IPMTA3OFfgMVWVbDs5rls',
#   'track_href': 'https://api.spotify.com/v1/tracks/5IPMTA3OFfgMVWVbDs5rls',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5IPMTA3OFfgMVWVbDs5rls',
#   'duration_ms': 213000,
#   'time_signature': 4},
#  {'danceability': 0.803,
#   'energy': 0.798,
#   'key': 6,
#   'loudness': -4.855,
#   'mode': 0,
#   'speechiness': 0.173,
#   'acousticness': 0.0764,
#   'instrumentalness': 0,
#   'liveness': 0.0775,
#   'valence': 0.761,
#   'tempo': 88.018,
#   'type': 'audio_features',
#   'id': '09sfSrdnB12Xp8zygVG2QX',
#   'uri': 'spotify:track:09sfSrdnB12Xp8zygVG2QX',
#   'track_href': 'https://api.spotify.com/v1/tracks/09sfSrdnB12Xp8zygVG2QX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/09sfSrdnB12Xp8zygVG2QX',
#   'duration_ms': 190440,
#   'time_signature': 4},
#  {'danceability': 0.655,
#   'energy': 0.879,
#   'key': 0,
#   'loudness': -4.743,
#   'mode': 1,
#   'speechiness': 0.235,
#   'acousticness': 0.0321,
#   'instrumentalness': 6.97e-06,
#   'liveness': 0.0679,
#   'valence': 0.657,
#   'tempo': 184.027,
#   'type': 'audio_features',
#   'id': '4DOrr7LlCkrs3DZkrE3sLe',
#   'uri': 'spotify:track:4DOrr7LlCkrs3DZkrE3sLe',
#   'track_href': 'https://api.spotify.com/v1/tracks/4DOrr7LlCkrs3DZkrE3sLe',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4DOrr7LlCkrs3DZkrE3sLe',
#   'duration_ms': 213000,
#   'time_signature': 4},
#  {'danceability': 0.85,
#   'energy': 0.854,
#   'key': 0,
#   'loudness': -5.157,
#   'mode': 1,
#   'speechiness': 0.0561,
#   'acousticness': 0.388,
#   'instrumentalness': 3.7e-06,
#   'liveness': 0.0692,
#   'valence': 0.758,
#   'tempo': 96.009,
#   'type': 'audio_features',
#   'id': '0vpNjIisLT117QT7KjJMRN',
#   'uri': 'spotify:track:0vpNjIisLT117QT7KjJMRN',
#   'track_href': 'https://api.spotify.com/v1/tracks/0vpNjIisLT117QT7KjJMRN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0vpNjIisLT117QT7KjJMRN',
#   'duration_ms': 192574,
#   'time_signature': 4},
#  {'danceability': 0.762,
#   'energy': 0.79,
#   'key': 9,
#   'loudness': -3.944,
#   'mode': 0,
#   'speechiness': 0.0988,
#   'acousticness': 0.109,
#   'instrumentalness': 2.73e-06,
#   'liveness': 0.172,
#   'valence': 0.748,
#   'tempo': 129.988,
#   'type': 'audio_features',
#   'id': '3mlme87GQeixJ5EUwwUDOO',
#   'uri': 'spotify:track:3mlme87GQeixJ5EUwwUDOO',
#   'track_href': 'https://api.spotify.com/v1/tracks/3mlme87GQeixJ5EUwwUDOO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3mlme87GQeixJ5EUwwUDOO',
#   'duration_ms': 223360,
#   'time_signature': 4},
#  {'danceability': 0.678,
#   'energy': 0.872,
#   'key': 5,
#   'loudness': -4.469,
#   'mode': 0,
#   'speechiness': 0.243,
#   'acousticness': 0.283,
#   'instrumentalness': 0,
#   'liveness': 0.299,
#   'valence': 0.885,
#   'tempo': 184.066,
#   'type': 'audio_features',
#   'id': '6gEruXk4M9roUYy8kIHZ8n',
#   'uri': 'spotify:track:6gEruXk4M9roUYy8kIHZ8n',
#   'track_href': 'https://api.spotify.com/v1/tracks/6gEruXk4M9roUYy8kIHZ8n',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6gEruXk4M9roUYy8kIHZ8n',
#   'duration_ms': 179227,
#   'time_signature': 4},
#  {'danceability': 0.655,
#   'energy': 0.879,
#   'key': 0,
#   'loudness': -4.743,
#   'mode': 1,
#   'speechiness': 0.235,
#   'acousticness': 0.0321,
#   'instrumentalness': 6.97e-06,
#   'liveness': 0.0679,
#   'valence': 0.657,
#   'tempo': 184.027,
#   'type': 'audio_features',
#   'id': '5ygQLeVhWaVCn6WKRAkPcq',
#   'uri': 'spotify:track:5ygQLeVhWaVCn6WKRAkPcq',
#   'track_href': 'https://api.spotify.com/v1/tracks/5ygQLeVhWaVCn6WKRAkPcq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5ygQLeVhWaVCn6WKRAkPcq',
#   'duration_ms': 213000,
#   'time_signature': 4},
#  {'danceability': 0.783,
#   'energy': 0.84,
#   'key': 1,
#   'loudness': -3.416,
#   'mode': 1,
#   'speechiness': 0.051,
#   'acousticness': 0.174,
#   'instrumentalness': 0,
#   'liveness': 0.412,
#   'valence': 0.838,
#   'tempo': 95.002,
#   'type': 'audio_features',
#   'id': '15WhJFfPoorEMo5kd1c2gn',
#   'uri': 'spotify:track:15WhJFfPoorEMo5kd1c2gn',
#   'track_href': 'https://api.spotify.com/v1/tracks/15WhJFfPoorEMo5kd1c2gn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/15WhJFfPoorEMo5kd1c2gn',
#   'duration_ms': 200480,
#   'time_signature': 4},
#  {'danceability': 0.783,
#   'energy': 0.84,
#   'key': 1,
#   'loudness': -3.416,
#   'mode': 1,
#   'speechiness': 0.051,
#   'acousticness': 0.174,
#   'instrumentalness': 0,
#   'liveness': 0.412,
#   'valence': 0.838,
#   'tempo': 95.002,
#   'type': 'audio_features',
#   'id': '7LOhhqPZncxksqDotM1YQq',
#   'uri': 'spotify:track:7LOhhqPZncxksqDotM1YQq',
#   'track_href': 'https://api.spotify.com/v1/tracks/7LOhhqPZncxksqDotM1YQq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7LOhhqPZncxksqDotM1YQq',
#   'duration_ms': 200480,
#   'time_signature': 4},
#  {'danceability': 0.773,
#   'energy': 0.8,
#   'key': 10,
#   'loudness': -3.17,
#   'mode': 0,
#   'speechiness': 0.0987,
#   'acousticness': 0.0613,
#   'instrumentalness': 0.00403,
#   'liveness': 0.0327,
#   'valence': 0.842,
#   'tempo': 89.988,
#   'type': 'audio_features',
#   'id': '2dl5K2ScW7jYhAhuem06cm',
#   'uri': 'spotify:track:2dl5K2ScW7jYhAhuem06cm',
#   'track_href': 'https://api.spotify.com/v1/tracks/2dl5K2ScW7jYhAhuem06cm',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2dl5K2ScW7jYhAhuem06cm',
#   'duration_ms': 184507,
#   'time_signature': 4},
#  {'danceability': 0.85,
#   'energy': 0.854,
#   'key': 0,
#   'loudness': -5.157,
#   'mode': 1,
#   'speechiness': 0.0561,
#   'acousticness': 0.388,
#   'instrumentalness': 3.7e-06,
#   'liveness': 0.0692,
#   'valence': 0.758,
#   'tempo': 96.009,
#   'type': 'audio_features',
#   'id': '2zNgaTy0ikJfFMSPD1Nyyd',
#   'uri': 'spotify:track:2zNgaTy0ikJfFMSPD1Nyyd',
#   'track_href': 'https://api.spotify.com/v1/tracks/2zNgaTy0ikJfFMSPD1Nyyd',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2zNgaTy0ikJfFMSPD1Nyyd',
#   'duration_ms': 192574,
#   'time_signature': 4},
#  {'danceability': 0.825,
#   'energy': 0.771,
#   'key': 2,
#   'loudness': -2.515,
#   'mode': 0,
#   'speechiness': 0.0796,
#   'acousticness': 0.075,
#   'instrumentalness': 3.89e-05,
#   'liveness': 0.093,
#   'valence': 0.929,
#   'tempo': 154.001,
#   'type': 'audio_features',
#   'id': '3ymdUMzgylwrSfpxdlCUWV',
#   'uri': 'spotify:track:3ymdUMzgylwrSfpxdlCUWV',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ymdUMzgylwrSfpxdlCUWV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ymdUMzgylwrSfpxdlCUWV',
#   'duration_ms': 212416,
#   'time_signature': 4},
#  {'danceability': 0.691,
#   'energy': 0.894,
#   'key': 9,
#   'loudness': -1.681,
#   'mode': 0,
#   'speechiness': 0.115,
#   'acousticness': 0.291,
#   'instrumentalness': 0,
#   'liveness': 0.104,
#   'valence': 0.623,
#   'tempo': 184.018,
#   'type': 'audio_features',
#   'id': '3GnzoWqvd6XvSRjli1uCUC',
#   'uri': 'spotify:track:3GnzoWqvd6XvSRjli1uCUC',
#   'track_href': 'https://api.spotify.com/v1/tracks/3GnzoWqvd6XvSRjli1uCUC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3GnzoWqvd6XvSRjli1uCUC',
#   'duration_ms': 241880,
#   'time_signature': 4},
#  {'danceability': 0.808,
#   'energy': 0.697,
#   'key': 10,
#   'loudness': -5.899,
#   'mode': 1,
#   'speechiness': 0.241,
#   'acousticness': 0.041,
#   'instrumentalness': 0,
#   'liveness': 0.0546,
#   'valence': 0.554,
#   'tempo': 95.06,
#   'type': 'audio_features',
#   'id': '5gflgO9EPbIBf16n5TKnQS',
#   'uri': 'spotify:track:5gflgO9EPbIBf16n5TKnQS',
#   'track_href': 'https://api.spotify.com/v1/tracks/5gflgO9EPbIBf16n5TKnQS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5gflgO9EPbIBf16n5TKnQS',
#   'duration_ms': 232020,
#   'time_signature': 4},
#  {'danceability': 0.846,
#   'energy': 0.842,
#   'key': 8,
#   'loudness': -4.066,
#   'mode': 1,
#   'speechiness': 0.0783,
#   'acousticness': 0.23,
#   'instrumentalness': 6.88e-06,
#   'liveness': 0.174,
#   'valence': 0.762,
#   'tempo': 93.962,
#   'type': 'audio_features',
#   'id': '4Rlu9UT8e3UbtuPsNEZOMF',
#   'uri': 'spotify:track:4Rlu9UT8e3UbtuPsNEZOMF',
#   'track_href': 'https://api.spotify.com/v1/tracks/4Rlu9UT8e3UbtuPsNEZOMF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4Rlu9UT8e3UbtuPsNEZOMF',
#   'duration_ms': 178800,
#   'time_signature': 4},
#  {'danceability': 0.639,
#   'energy': 0.869,
#   'key': 11,
#   'loudness': -4.024,
#   'mode': 1,
#   'speechiness': 0.147,
#   'acousticness': 0.27,
#   'instrumentalness': 0,
#   'liveness': 0.0802,
#   'valence': 0.767,
#   'tempo': 169.801,
#   'type': 'audio_features',
#   'id': '5q2JbCNi4FcnglgPfxcV65',
#   'uri': 'spotify:track:5q2JbCNi4FcnglgPfxcV65',
#   'track_href': 'https://api.spotify.com/v1/tracks/5q2JbCNi4FcnglgPfxcV65',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5q2JbCNi4FcnglgPfxcV65',
#   'duration_ms': 307910,
#   'time_signature': 4},
#  {'danceability': 0.846,
#   'energy': 0.842,
#   'key': 8,
#   'loudness': -4.066,
#   'mode': 1,
#   'speechiness': 0.0783,
#   'acousticness': 0.23,
#   'instrumentalness': 6.88e-06,
#   'liveness': 0.174,
#   'valence': 0.762,
#   'tempo': 93.962,
#   'type': 'audio_features',
#   'id': '4iAKnWGo5U4tGvlJgzlxjn',
#   'uri': 'spotify:track:4iAKnWGo5U4tGvlJgzlxjn',
#   'track_href': 'https://api.spotify.com/v1/tracks/4iAKnWGo5U4tGvlJgzlxjn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4iAKnWGo5U4tGvlJgzlxjn',
#   'duration_ms': 178800,
#   'time_signature': 4},
#  {'danceability': 0.806,
#   'energy': 0.929,
#   'key': 10,
#   'loudness': -3.017,
#   'mode': 1,
#   'speechiness': 0.121,
#   'acousticness': 0.263,
#   'instrumentalness': 0,
#   'liveness': 0.0622,
#   'valence': 0.602,
#   'tempo': 97.99,
#   'type': 'audio_features',
#   'id': '4YW2Fr25fHwUt6qgvM1iE1',
#   'uri': 'spotify:track:4YW2Fr25fHwUt6qgvM1iE1',
#   'track_href': 'https://api.spotify.com/v1/tracks/4YW2Fr25fHwUt6qgvM1iE1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4YW2Fr25fHwUt6qgvM1iE1',
#   'duration_ms': 232373,
#   'time_signature': 4},
#  {'danceability': 0.783,
#   'energy': 0.84,
#   'key': 1,
#   'loudness': -3.416,
#   'mode': 1,
#   'speechiness': 0.051,
#   'acousticness': 0.174,
#   'instrumentalness': 0,
#   'liveness': 0.412,
#   'valence': 0.838,
#   'tempo': 95.002,
#   'type': 'audio_features',
#   'id': '7KrRbJRtIvbubVQvP6fhXn',
#   'uri': 'spotify:track:7KrRbJRtIvbubVQvP6fhXn',
#   'track_href': 'https://api.spotify.com/v1/tracks/7KrRbJRtIvbubVQvP6fhXn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7KrRbJRtIvbubVQvP6fhXn',
#   'duration_ms': 200480,
#   'time_signature': 4},
#  {'danceability': 0.856,
#   'energy': 0.894,
#   'key': 10,
#   'loudness': -4.994,
#   'mode': 0,
#   'speechiness': 0.116,
#   'acousticness': 0.157,
#   'instrumentalness': 0,
#   'liveness': 0.112,
#   'valence': 0.916,
#   'tempo': 104.042,
#   'type': 'audio_features',
#   'id': '0smQWysb4n7WOVGv5YMLnF',
#   'uri': 'spotify:track:0smQWysb4n7WOVGv5YMLnF',
#   'track_href': 'https://api.spotify.com/v1/tracks/0smQWysb4n7WOVGv5YMLnF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0smQWysb4n7WOVGv5YMLnF',
#   'duration_ms': 157049,
#   'time_signature': 4},
#  {'danceability': 0.85,
#   'energy': 0.854,
#   'key': 0,
#   'loudness': -5.157,
#   'mode': 1,
#   'speechiness': 0.0561,
#   'acousticness': 0.388,
#   'instrumentalness': 3.7e-06,
#   'liveness': 0.0692,
#   'valence': 0.758,
#   'tempo': 96.009,
#   'type': 'audio_features',
#   'id': '5vaPap61OHCXtwnnhTwhNh',
#   'uri': 'spotify:track:5vaPap61OHCXtwnnhTwhNh',
#   'track_href': 'https://api.spotify.com/v1/tracks/5vaPap61OHCXtwnnhTwhNh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5vaPap61OHCXtwnnhTwhNh',
#   'duration_ms': 192574,
#   'time_signature': 4},
#  {'danceability': 0.687,
#   'energy': 0.907,
#   'key': 0,
#   'loudness': -5.917,
#   'mode': 1,
#   'speechiness': 0.0341,
#   'acousticness': 0.00105,
#   'instrumentalness': 0.000149,
#   'liveness': 0.26,
#   'valence': 0.661,
#   'tempo': 127.971,
#   'type': 'audio_features',
#   'id': '0bdL8X3MrX51dRz231BFtv',
#   'uri': 'spotify:track:0bdL8X3MrX51dRz231BFtv',
#   'track_href': 'https://api.spotify.com/v1/tracks/0bdL8X3MrX51dRz231BFtv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0bdL8X3MrX51dRz231BFtv',
#   'duration_ms': 199027,
#   'time_signature': 4},
#  {'danceability': 0.783,
#   'energy': 0.84,
#   'key': 1,
#   'loudness': -3.416,
#   'mode': 1,
#   'speechiness': 0.051,
#   'acousticness': 0.174,
#   'instrumentalness': 0,
#   'liveness': 0.412,
#   'valence': 0.838,
#   'tempo': 95.002,
#   'type': 'audio_features',
#   'id': '0JLps8WnbWTYwLnY1kQe3u',
#   'uri': 'spotify:track:0JLps8WnbWTYwLnY1kQe3u',
#   'track_href': 'https://api.spotify.com/v1/tracks/0JLps8WnbWTYwLnY1kQe3u',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0JLps8WnbWTYwLnY1kQe3u',
#   'duration_ms': 200480,
#   'time_signature': 4},
#  {'danceability': 0.714,
#   'energy': 0.626,
#   'key': 5,
#   'loudness': -4.655,
#   'mode': 0,
#   'speechiness': 0.423,
#   'acousticness': 0.26,
#   'instrumentalness': 0,
#   'liveness': 0.284,
#   'valence': 0.512,
#   'tempo': 76.625,
#   'type': 'audio_features',
#   'id': '0LQsM0KYkSyCdN6TCo63vp',
#   'uri': 'spotify:track:0LQsM0KYkSyCdN6TCo63vp',
#   'track_href': 'https://api.spotify.com/v1/tracks/0LQsM0KYkSyCdN6TCo63vp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0LQsM0KYkSyCdN6TCo63vp',
#   'duration_ms': 315440,
#   'time_signature': 4},
#  {'danceability': 0.639,
#   'energy': 0.943,
#   'key': 5,
#   'loudness': -3.542,
#   'mode': 1,
#   'speechiness': 0.136,
#   'acousticness': 0.0462,
#   'instrumentalness': 0,
#   'liveness': 0.141,
#   'valence': 0.639,
#   'tempo': 198.051,
#   'type': 'audio_features',
#   'id': '4Zgr1LL7elkbzgi0GKKV7E',
#   'uri': 'spotify:track:4Zgr1LL7elkbzgi0GKKV7E',
#   'track_href': 'https://api.spotify.com/v1/tracks/4Zgr1LL7elkbzgi0GKKV7E',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4Zgr1LL7elkbzgi0GKKV7E',
#   'duration_ms': 197053,
#   'time_signature': 4},
#  {'danceability': 0.715,
#   'energy': 0.748,
#   'key': 1,
#   'loudness': -4.897,
#   'mode': 1,
#   'speechiness': 0.0811,
#   'acousticness': 0.371,
#   'instrumentalness': 0,
#   'liveness': 0.137,
#   'valence': 0.91,
#   'tempo': 170.033,
#   'type': 'audio_features',
#   'id': '3u8fKvW5X1zvrsweW5h2xa',
#   'uri': 'spotify:track:3u8fKvW5X1zvrsweW5h2xa',
#   'track_href': 'https://api.spotify.com/v1/tracks/3u8fKvW5X1zvrsweW5h2xa',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3u8fKvW5X1zvrsweW5h2xa',
#   'duration_ms': 204720,
#   'time_signature': 4},
#  {'danceability': 0.639,
#   'energy': 0.943,
#   'key': 5,
#   'loudness': -3.542,
#   'mode': 1,
#   'speechiness': 0.136,
#   'acousticness': 0.0462,
#   'instrumentalness': 0,
#   'liveness': 0.141,
#   'valence': 0.639,
#   'tempo': 198.051,
#   'type': 'audio_features',
#   'id': '5ydWPGC2MZ995wd3RmVeyu',
#   'uri': 'spotify:track:5ydWPGC2MZ995wd3RmVeyu',
#   'track_href': 'https://api.spotify.com/v1/tracks/5ydWPGC2MZ995wd3RmVeyu',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5ydWPGC2MZ995wd3RmVeyu',
#   'duration_ms': 197053,
#   'time_signature': 4},
#  {'danceability': 0.823,
#   'energy': 0.721,
#   'key': 6,
#   'loudness': -5.164,
#   'mode': 0,
#   'speechiness': 0.0408,
#   'acousticness': 0.258,
#   'instrumentalness': 0,
#   'liveness': 0.0593,
#   'valence': 0.669,
#   'tempo': 93.976,
#   'type': 'audio_features',
#   'id': '4bisT9khxJYFKaoG8pxq5h',
#   'uri': 'spotify:track:4bisT9khxJYFKaoG8pxq5h',
#   'track_href': 'https://api.spotify.com/v1/tracks/4bisT9khxJYFKaoG8pxq5h',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4bisT9khxJYFKaoG8pxq5h',
#   'duration_ms': 188467,
#   'time_signature': 4},
#  {'danceability': 0.85,
#   'energy': 0.854,
#   'key': 0,
#   'loudness': -5.157,
#   'mode': 1,
#   'speechiness': 0.0561,
#   'acousticness': 0.388,
#   'instrumentalness': 3.7e-06,
#   'liveness': 0.0692,
#   'valence': 0.758,
#   'tempo': 96.009,
#   'type': 'audio_features',
#   'id': '7czq2mY29RXx6c3IYXe4Hk',
#   'uri': 'spotify:track:7czq2mY29RXx6c3IYXe4Hk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7czq2mY29RXx6c3IYXe4Hk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7czq2mY29RXx6c3IYXe4Hk',
#   'duration_ms': 192574,
#   'time_signature': 4},
#  {'danceability': 0.624,
#   'energy': 0.772,
#   'key': 7,
#   'loudness': -4.687,
#   'mode': 0,
#   'speechiness': 0.165,
#   'acousticness': 0.178,
#   'instrumentalness': 0,
#   'liveness': 0.11,
#   'valence': 0.589,
#   'tempo': 172.014,
#   'type': 'audio_features',
#   'id': '09qIdioXLJPGXAM9zsy20v',
#   'uri': 'spotify:track:09qIdioXLJPGXAM9zsy20v',
#   'track_href': 'https://api.spotify.com/v1/tracks/09qIdioXLJPGXAM9zsy20v',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/09qIdioXLJPGXAM9zsy20v',
#   'duration_ms': 222240,
#   'time_signature': 4},
#  {'danceability': 0.687,
#   'energy': 0.806,
#   'key': 1,
#   'loudness': -6.019,
#   'mode': 0,
#   'speechiness': 0.0549,
#   'acousticness': 0.0358,
#   'instrumentalness': 5.83e-06,
#   'liveness': 0.0569,
#   'valence': 0.534,
#   'tempo': 176.064,
#   'type': 'audio_features',
#   'id': '4IKKJbb7eTChd0YbE2dEkp',
#   'uri': 'spotify:track:4IKKJbb7eTChd0YbE2dEkp',
#   'track_href': 'https://api.spotify.com/v1/tracks/4IKKJbb7eTChd0YbE2dEkp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4IKKJbb7eTChd0YbE2dEkp',
#   'duration_ms': 189040,
#   'time_signature': 4},
#  {'danceability': 0.774,
#   'energy': 0.654,
#   'key': 1,
#   'loudness': -6.932,
#   'mode': 1,
#   'speechiness': 0.234,
#   'acousticness': 0.192,
#   'instrumentalness': 0,
#   'liveness': 0.303,
#   'valence': 0.846,
#   'tempo': 166.001,
#   'type': 'audio_features',
#   'id': '6n5hSi8Mdyee0XvsmIffeV',
#   'uri': 'spotify:track:6n5hSi8Mdyee0XvsmIffeV',
#   'track_href': 'https://api.spotify.com/v1/tracks/6n5hSi8Mdyee0XvsmIffeV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6n5hSi8Mdyee0XvsmIffeV',
#   'duration_ms': 477675,
#   'time_signature': 4},
#  {'danceability': 0.659,
#   'energy': 0.901,
#   'key': 7,
#   'loudness': -2.814,
#   'mode': 1,
#   'speechiness': 0.0358,
#   'acousticness': 0.0478,
#   'instrumentalness': 0,
#   'liveness': 0.148,
#   'valence': 0.704,
#   'tempo': 93.979,
#   'type': 'audio_features',
#   'id': '4qYXtaU8pxHmzWk8TOenEM',
#   'uri': 'spotify:track:4qYXtaU8pxHmzWk8TOenEM',
#   'track_href': 'https://api.spotify.com/v1/tracks/4qYXtaU8pxHmzWk8TOenEM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4qYXtaU8pxHmzWk8TOenEM',
#   'duration_ms': 210520,
#   'time_signature': 4},
#  {'danceability': 0.574,
#   'energy': 0.925,
#   'key': 6,
#   'loudness': -1.232,
#   'mode': 0,
#   'speechiness': 0.101,
#   'acousticness': 0.0966,
#   'instrumentalness': 0,
#   'liveness': 0.238,
#   'valence': 0.51,
#   'tempo': 104.82,
#   'type': 'audio_features',
#   'id': '4mim2LONFWdHFxH8TQVczc',
#   'uri': 'spotify:track:4mim2LONFWdHFxH8TQVczc',
#   'track_href': 'https://api.spotify.com/v1/tracks/4mim2LONFWdHFxH8TQVczc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4mim2LONFWdHFxH8TQVczc',
#   'duration_ms': 218000,
#   'time_signature': 4},
#  {'danceability': 0.846,
#   'energy': 0.842,
#   'key': 8,
#   'loudness': -4.066,
#   'mode': 1,
#   'speechiness': 0.0783,
#   'acousticness': 0.23,
#   'instrumentalness': 6.88e-06,
#   'liveness': 0.174,
#   'valence': 0.762,
#   'tempo': 93.962,
#   'type': 'audio_features',
#   'id': '59qbMFhOGq9qZay1ZHvbPP',
#   'uri': 'spotify:track:59qbMFhOGq9qZay1ZHvbPP',
#   'track_href': 'https://api.spotify.com/v1/tracks/59qbMFhOGq9qZay1ZHvbPP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/59qbMFhOGq9qZay1ZHvbPP',
#   'duration_ms': 178800,
#   'time_signature': 4},
#  {'danceability': 0.768,
#   'energy': 0.876,
#   'key': 7,
#   'loudness': -4.902,
#   'mode': 1,
#   'speechiness': 0.125,
#   'acousticness': 0.151,
#   'instrumentalness': 0,
#   'liveness': 0.348,
#   'valence': 0.892,
#   'tempo': 171.956,
#   'type': 'audio_features',
#   'id': '6FFUyFocgvYlHQVjuMKX0p',
#   'uri': 'spotify:track:6FFUyFocgvYlHQVjuMKX0p',
#   'track_href': 'https://api.spotify.com/v1/tracks/6FFUyFocgvYlHQVjuMKX0p',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6FFUyFocgvYlHQVjuMKX0p',
#   'duration_ms': 410776,
#   'time_signature': 4},
#  {'danceability': 0.783,
#   'energy': 0.84,
#   'key': 1,
#   'loudness': -3.416,
#   'mode': 1,
#   'speechiness': 0.051,
#   'acousticness': 0.174,
#   'instrumentalness': 0,
#   'liveness': 0.412,
#   'valence': 0.838,
#   'tempo': 95.002,
#   'type': 'audio_features',
#   'id': '1dKTq81nnLnqP4JkivZAPy',
#   'uri': 'spotify:track:1dKTq81nnLnqP4JkivZAPy',
#   'track_href': 'https://api.spotify.com/v1/tracks/1dKTq81nnLnqP4JkivZAPy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1dKTq81nnLnqP4JkivZAPy',
#   'duration_ms': 200480,
#   'time_signature': 4},
#  {'danceability': 0.741,
#   'energy': 0.799,
#   'key': 9,
#   'loudness': -4.035,
#   'mode': 0,
#   'speechiness': 0.263,
#   'acousticness': 0.296,
#   'instrumentalness': 0,
#   'liveness': 0.239,
#   'valence': 0.956,
#   'tempo': 87.061,
#   'type': 'audio_features',
#   'id': '5rKEC4enuOXJ37zx9OCz2G',
#   'uri': 'spotify:track:5rKEC4enuOXJ37zx9OCz2G',
#   'track_href': 'https://api.spotify.com/v1/tracks/5rKEC4enuOXJ37zx9OCz2G',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5rKEC4enuOXJ37zx9OCz2G',
#   'duration_ms': 246890,
#   'time_signature': 4},
#  {'danceability': 0.783,
#   'energy': 0.84,
#   'key': 1,
#   'loudness': -3.416,
#   'mode': 1,
#   'speechiness': 0.051,
#   'acousticness': 0.174,
#   'instrumentalness': 0,
#   'liveness': 0.412,
#   'valence': 0.838,
#   'tempo': 95.002,
#   'type': 'audio_features',
#   'id': '4biEN3aGfcTCZjVVhjd25R',
#   'uri': 'spotify:track:4biEN3aGfcTCZjVVhjd25R',
#   'track_href': 'https://api.spotify.com/v1/tracks/4biEN3aGfcTCZjVVhjd25R',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4biEN3aGfcTCZjVVhjd25R',
#   'duration_ms': 200480,
#   'time_signature': 4},
#  {'danceability': 0.507,
#   'energy': 0.583,
#   'key': 1,
#   'loudness': -7.958,
#   'mode': 0,
#   'speechiness': 0.0664,
#   'acousticness': 0.0509,
#   'instrumentalness': 2.11e-06,
#   'liveness': 0.0845,
#   'valence': 0.24,
#   'tempo': 165.786,
#   'type': 'audio_features',
#   'id': '5Hiu520lWG4YPrMugnNnkP',
#   'uri': 'spotify:track:5Hiu520lWG4YPrMugnNnkP',
#   'track_href': 'https://api.spotify.com/v1/tracks/5Hiu520lWG4YPrMugnNnkP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5Hiu520lWG4YPrMugnNnkP',
#   'duration_ms': 261143,
#   'time_signature': 4},
#  {'danceability': 0.846,
#   'energy': 0.842,
#   'key': 8,
#   'loudness': -4.066,
#   'mode': 1,
#   'speechiness': 0.0783,
#   'acousticness': 0.23,
#   'instrumentalness': 6.88e-06,
#   'liveness': 0.174,
#   'valence': 0.762,
#   'tempo': 93.962,
#   'type': 'audio_features',
#   'id': '3LBxirjR6hv0Pn4I2N9TfF',
#   'uri': 'spotify:track:3LBxirjR6hv0Pn4I2N9TfF',
#   'track_href': 'https://api.spotify.com/v1/tracks/3LBxirjR6hv0Pn4I2N9TfF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3LBxirjR6hv0Pn4I2N9TfF',
#   'duration_ms': 178800,
#   'time_signature': 4},
#  {'danceability': 0.799,
#   'energy': 0.787,
#   'key': 11,
#   'loudness': -5.02,
#   'mode': 1,
#   'speechiness': 0.0489,
#   'acousticness': 0.0241,
#   'instrumentalness': 0.00053,
#   'liveness': 0.408,
#   'valence': 0.962,
#   'tempo': 128.033,
#   'type': 'audio_features',
#   'id': '6zcnGbjNk1kyoSc1VgkTIm',
#   'uri': 'spotify:track:6zcnGbjNk1kyoSc1VgkTIm',
#   'track_href': 'https://api.spotify.com/v1/tracks/6zcnGbjNk1kyoSc1VgkTIm',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6zcnGbjNk1kyoSc1VgkTIm',
#   'duration_ms': 237796,
#   'time_signature': 4},
#  {'danceability': 0.803,
#   'energy': 0.798,
#   'key': 6,
#   'loudness': -4.855,
#   'mode': 0,
#   'speechiness': 0.173,
#   'acousticness': 0.0764,
#   'instrumentalness': 0,
#   'liveness': 0.0775,
#   'valence': 0.761,
#   'tempo': 88.018,
#   'type': 'audio_features',
#   'id': '0qA0bwxgHMLqF2CeXcwcaX',
#   'uri': 'spotify:track:0qA0bwxgHMLqF2CeXcwcaX',
#   'track_href': 'https://api.spotify.com/v1/tracks/0qA0bwxgHMLqF2CeXcwcaX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0qA0bwxgHMLqF2CeXcwcaX',
#   'duration_ms': 190440,
#   'time_signature': 4},
#  {'danceability': 0.753,
#   'energy': 0.862,
#   'key': 5,
#   'loudness': -5.682,
#   'mode': 0,
#   'speechiness': 0.0864,
#   'acousticness': 0.0384,
#   'instrumentalness': 0.000204,
#   'liveness': 0.34,
#   'valence': 0.558,
#   'tempo': 99.994,
#   'type': 'audio_features',
#   'id': '2VUTAujEdkpmHlwXZPEph9',
#   'uri': 'spotify:track:2VUTAujEdkpmHlwXZPEph9',
#   'track_href': 'https://api.spotify.com/v1/tracks/2VUTAujEdkpmHlwXZPEph9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2VUTAujEdkpmHlwXZPEph9',
#   'duration_ms': 234507,
#   'time_signature': 4},
#  {'danceability': 0.783,
#   'energy': 0.84,
#   'key': 1,
#   'loudness': -3.416,
#   'mode': 1,
#   'speechiness': 0.051,
#   'acousticness': 0.174,
#   'instrumentalness': 0,
#   'liveness': 0.412,
#   'valence': 0.838,
#   'tempo': 95.002,
#   'type': 'audio_features',
#   'id': '3pY3BzQWRWvPuqWerJNmDj',
#   'uri': 'spotify:track:3pY3BzQWRWvPuqWerJNmDj',
#   'track_href': 'https://api.spotify.com/v1/tracks/3pY3BzQWRWvPuqWerJNmDj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3pY3BzQWRWvPuqWerJNmDj',
#   'duration_ms': 200480,
#   'time_signature': 4},
#  {'danceability': 0.706,
#   'energy': 0.86,
#   'key': 5,
#   'loudness': -3.014,
#   'mode': 0,
#   'speechiness': 0.0604,
#   'acousticness': 0.172,
#   'instrumentalness': 0,
#   'liveness': 0.183,
#   'valence': 0.505,
#   'tempo': 100.094,
#   'type': 'audio_features',
#   'id': '3AQ1zVx39FvB4yH0bjGgPm',
#   'uri': 'spotify:track:3AQ1zVx39FvB4yH0bjGgPm',
#   'track_href': 'https://api.spotify.com/v1/tracks/3AQ1zVx39FvB4yH0bjGgPm',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3AQ1zVx39FvB4yH0bjGgPm',
#   'duration_ms': 225480,
#   'time_signature': 4},
#  {'danceability': 0.655,
#   'energy': 0.879,
#   'key': 0,
#   'loudness': -4.743,
#   'mode': 1,
#   'speechiness': 0.235,
#   'acousticness': 0.0321,
#   'instrumentalness': 6.97e-06,
#   'liveness': 0.0679,
#   'valence': 0.657,
#   'tempo': 184.027,
#   'type': 'audio_features',
#   'id': '1UF8a4K1wlRqfghmNwVOxa',
#   'uri': 'spotify:track:1UF8a4K1wlRqfghmNwVOxa',
#   'track_href': 'https://api.spotify.com/v1/tracks/1UF8a4K1wlRqfghmNwVOxa',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1UF8a4K1wlRqfghmNwVOxa',
#   'duration_ms': 213000,
#   'time_signature': 4},
#  {'danceability': 0.659,
#   'energy': 0.88,
#   'key': 2,
#   'loudness': -4.254,
#   'mode': 1,
#   'speechiness': 0.0595,
#   'acousticness': 0.0383,
#   'instrumentalness': 0.176,
#   'liveness': 0.102,
#   'valence': 0.652,
#   'tempo': 179.985,
#   'type': 'audio_features',
#   'id': '50JYk1mnIkosI80PKyqZmV',
#   'uri': 'spotify:track:50JYk1mnIkosI80PKyqZmV',
#   'track_href': 'https://api.spotify.com/v1/tracks/50JYk1mnIkosI80PKyqZmV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/50JYk1mnIkosI80PKyqZmV',
#   'duration_ms': 252107,
#   'time_signature': 4},
#  {'danceability': 0.783,
#   'energy': 0.84,
#   'key': 1,
#   'loudness': -3.416,
#   'mode': 1,
#   'speechiness': 0.051,
#   'acousticness': 0.174,
#   'instrumentalness': 0,
#   'liveness': 0.412,
#   'valence': 0.838,
#   'tempo': 95.002,
#   'type': 'audio_features',
#   'id': '3pY3BzQWRWvPuqWerJNmDj',
#   'uri': 'spotify:track:3pY3BzQWRWvPuqWerJNmDj',
#   'track_href': 'https://api.spotify.com/v1/tracks/3pY3BzQWRWvPuqWerJNmDj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3pY3BzQWRWvPuqWerJNmDj',
#   'duration_ms': 200480,
#   'time_signature': 4},
#  {'danceability': 0.692,
#   'energy': 0.781,
#   'key': 11,
#   'loudness': -3.868,
#   'mode': 1,
#   'speechiness': 0.0458,
#   'acousticness': 0.0392,
#   'instrumentalness': 6.72e-06,
#   'liveness': 0.332,
#   'valence': 0.492,
#   'tempo': 95.005,
#   'type': 'audio_features',
#   'id': '1TxDQxA1N4HyhvV0950h3Y',
#   'uri': 'spotify:track:1TxDQxA1N4HyhvV0950h3Y',
#   'track_href': 'https://api.spotify.com/v1/tracks/1TxDQxA1N4HyhvV0950h3Y',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1TxDQxA1N4HyhvV0950h3Y',
#   'duration_ms': 283733,
#   'time_signature': 4},
#  {'danceability': 0.655,
#   'energy': 0.879,
#   'key': 0,
#   'loudness': -4.743,
#   'mode': 1,
#   'speechiness': 0.235,
#   'acousticness': 0.0321,
#   'instrumentalness': 6.97e-06,
#   'liveness': 0.0679,
#   'valence': 0.657,
#   'tempo': 184.027,
#   'type': 'audio_features',
#   'id': '1UF8a4K1wlRqfghmNwVOxa',
#   'uri': 'spotify:track:1UF8a4K1wlRqfghmNwVOxa',
#   'track_href': 'https://api.spotify.com/v1/tracks/1UF8a4K1wlRqfghmNwVOxa',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1UF8a4K1wlRqfghmNwVOxa',
#   'duration_ms': 213000,
#   'time_signature': 4},
#  {'danceability': 0.744,
#   'energy': 0.837,
#   'key': 9,
#   'loudness': -5.082,
#   'mode': 0,
#   'speechiness': 0.0703,
#   'acousticness': 0.336,
#   'instrumentalness': 0,
#   'liveness': 0.229,
#   'valence': 0.706,
#   'tempo': 92.04,
#   'type': 'audio_features',
#   'id': '2MrP2Sv5Zbj1qckTKD1pVn',
#   'uri': 'spotify:track:2MrP2Sv5Zbj1qckTKD1pVn',
#   'track_href': 'https://api.spotify.com/v1/tracks/2MrP2Sv5Zbj1qckTKD1pVn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2MrP2Sv5Zbj1qckTKD1pVn',
#   'duration_ms': 293773,
#   'time_signature': 4},
#  {'danceability': 0.762,
#   'energy': 0.79,
#   'key': 9,
#   'loudness': -3.944,
#   'mode': 0,
#   'speechiness': 0.0988,
#   'acousticness': 0.109,
#   'instrumentalness': 2.73e-06,
#   'liveness': 0.172,
#   'valence': 0.748,
#   'tempo': 129.988,
#   'type': 'audio_features',
#   'id': '3thAyB6PgWKfRU58du0pXO',
#   'uri': 'spotify:track:3thAyB6PgWKfRU58du0pXO',
#   'track_href': 'https://api.spotify.com/v1/tracks/3thAyB6PgWKfRU58du0pXO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3thAyB6PgWKfRU58du0pXO',
#   'duration_ms': 223360,
#   'time_signature': 4},
#  {'danceability': 0.738,
#   'energy': 0.726,
#   'key': 8,
#   'loudness': -5.318,
#   'mode': 0,
#   'speechiness': 0.0735,
#   'acousticness': 0.0627,
#   'instrumentalness': 0,
#   'liveness': 0.288,
#   'valence': 0.836,
#   'tempo': 171.962,
#   'type': 'audio_features',
#   'id': '3xGZOoLTPTiXJ74AKf75G8',
#   'uri': 'spotify:track:3xGZOoLTPTiXJ74AKf75G8',
#   'track_href': 'https://api.spotify.com/v1/tracks/3xGZOoLTPTiXJ74AKf75G8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3xGZOoLTPTiXJ74AKf75G8',
#   'duration_ms': 274027,
#   'time_signature': 4},
#  {'danceability': 0.787,
#   'energy': 0.771,
#   'key': 4,
#   'loudness': -3.206,
#   'mode': 0,
#   'speechiness': 0.0563,
#   'acousticness': 0.291,
#   'instrumentalness': 5.65e-05,
#   'liveness': 0.172,
#   'valence': 0.701,
#   'tempo': 99.036,
#   'type': 'audio_features',
#   'id': '798C5xOa9Nz1AWSlp4yMC9',
#   'uri': 'spotify:track:798C5xOa9Nz1AWSlp4yMC9',
#   'track_href': 'https://api.spotify.com/v1/tracks/798C5xOa9Nz1AWSlp4yMC9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/798C5xOa9Nz1AWSlp4yMC9',
#   'duration_ms': 207853,
#   'time_signature': 4},
#  {'danceability': 0.69,
#   'energy': 0.802,
#   'key': 1,
#   'loudness': -7.54,
#   'mode': 1,
#   'speechiness': 0.0841,
#   'acousticness': 0.131,
#   'instrumentalness': 0,
#   'liveness': 0.0413,
#   'valence': 0.9,
#   'tempo': 88.023,
#   'type': 'audio_features',
#   'id': '5vaA5IARCuJtbSeeiFQ0r8',
#   'uri': 'spotify:track:5vaA5IARCuJtbSeeiFQ0r8',
#   'track_href': 'https://api.spotify.com/v1/tracks/5vaA5IARCuJtbSeeiFQ0r8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5vaA5IARCuJtbSeeiFQ0r8',
#   'duration_ms': 160654,
#   'time_signature': 4},
#  {'danceability': 0.659,
#   'energy': 0.901,
#   'key': 7,
#   'loudness': -2.814,
#   'mode': 1,
#   'speechiness': 0.0358,
#   'acousticness': 0.0478,
#   'instrumentalness': 0,
#   'liveness': 0.148,
#   'valence': 0.704,
#   'tempo': 93.979,
#   'type': 'audio_features',
#   'id': '0qH1ZjBGMxQWTgTNIt5dbS',
#   'uri': 'spotify:track:0qH1ZjBGMxQWTgTNIt5dbS',
#   'track_href': 'https://api.spotify.com/v1/tracks/0qH1ZjBGMxQWTgTNIt5dbS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0qH1ZjBGMxQWTgTNIt5dbS',
#   'duration_ms': 210520,
#   'time_signature': 4},
#  {'danceability': 0.783,
#   'energy': 0.84,
#   'key': 1,
#   'loudness': -3.416,
#   'mode': 1,
#   'speechiness': 0.051,
#   'acousticness': 0.174,
#   'instrumentalness': 0,
#   'liveness': 0.412,
#   'valence': 0.838,
#   'tempo': 95.002,
#   'type': 'audio_features',
#   'id': '45yK2YOnJRVZ3dftyCrfy8',
#   'uri': 'spotify:track:45yK2YOnJRVZ3dftyCrfy8',
#   'track_href': 'https://api.spotify.com/v1/tracks/45yK2YOnJRVZ3dftyCrfy8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/45yK2YOnJRVZ3dftyCrfy8',
#   'duration_ms': 200480,
#   'time_signature': 4},
#  {'danceability': 0.783,
#   'energy': 0.84,
#   'key': 1,
#   'loudness': -3.416,
#   'mode': 1,
#   'speechiness': 0.051,
#   'acousticness': 0.174,
#   'instrumentalness': 0,
#   'liveness': 0.412,
#   'valence': 0.838,
#   'tempo': 95.002,
#   'type': 'audio_features',
#   'id': '5GBgwWqMwGhnJD08r9hVOU',
#   'uri': 'spotify:track:5GBgwWqMwGhnJD08r9hVOU',
#   'track_href': 'https://api.spotify.com/v1/tracks/5GBgwWqMwGhnJD08r9hVOU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5GBgwWqMwGhnJD08r9hVOU',
#   'duration_ms': 200480,
#   'time_signature': 4},
#  {'danceability': 0.85,
#   'energy': 0.854,
#   'key': 0,
#   'loudness': -5.157,
#   'mode': 1,
#   'speechiness': 0.0561,
#   'acousticness': 0.388,
#   'instrumentalness': 3.7e-06,
#   'liveness': 0.0692,
#   'valence': 0.758,
#   'tempo': 96.009,
#   'type': 'audio_features',
#   'id': '5ahstfXV0KjmlfSx99zyqZ',
#   'uri': 'spotify:track:5ahstfXV0KjmlfSx99zyqZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/5ahstfXV0KjmlfSx99zyqZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5ahstfXV0KjmlfSx99zyqZ',
#   'duration_ms': 192574,
#   'time_signature': 4},
#  {'danceability': 0.687,
#   'energy': 0.806,
#   'key': 1,
#   'loudness': -6.019,
#   'mode': 0,
#   'speechiness': 0.0549,
#   'acousticness': 0.0358,
#   'instrumentalness': 5.83e-06,
#   'liveness': 0.0569,
#   'valence': 0.534,
#   'tempo': 176.064,
#   'type': 'audio_features',
#   'id': '4vM4AG9r9LIjmWD2D87YlC',
#   'uri': 'spotify:track:4vM4AG9r9LIjmWD2D87YlC',
#   'track_href': 'https://api.spotify.com/v1/tracks/4vM4AG9r9LIjmWD2D87YlC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4vM4AG9r9LIjmWD2D87YlC',
#   'duration_ms': 189040,
#   'time_signature': 4},
#  {'danceability': 0.687,
#   'energy': 0.806,
#   'key': 1,
#   'loudness': -6.019,
#   'mode': 0,
#   'speechiness': 0.0549,
#   'acousticness': 0.0358,
#   'instrumentalness': 5.83e-06,
#   'liveness': 0.0569,
#   'valence': 0.534,
#   'tempo': 176.064,
#   'type': 'audio_features',
#   'id': '1N53scFPKuxI83pGnDgTHC',
#   'uri': 'spotify:track:1N53scFPKuxI83pGnDgTHC',
#   'track_href': 'https://api.spotify.com/v1/tracks/1N53scFPKuxI83pGnDgTHC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1N53scFPKuxI83pGnDgTHC',
#   'duration_ms': 189040,
#   'time_signature': 4},
#  {'danceability': 0.846,
#   'energy': 0.842,
#   'key': 8,
#   'loudness': -4.066,
#   'mode': 1,
#   'speechiness': 0.0783,
#   'acousticness': 0.23,
#   'instrumentalness': 6.88e-06,
#   'liveness': 0.174,
#   'valence': 0.762,
#   'tempo': 93.962,
#   'type': 'audio_features',
#   'id': '5MrGSuwjXPOHSJoowKPUgp',
#   'uri': 'spotify:track:5MrGSuwjXPOHSJoowKPUgp',
#   'track_href': 'https://api.spotify.com/v1/tracks/5MrGSuwjXPOHSJoowKPUgp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5MrGSuwjXPOHSJoowKPUgp',
#   'duration_ms': 178800,
#   'time_signature': 4},
#  {'danceability': 0.803,
#   'energy': 0.798,
#   'key': 6,
#   'loudness': -4.855,
#   'mode': 0,
#   'speechiness': 0.173,
#   'acousticness': 0.0764,
#   'instrumentalness': 0,
#   'liveness': 0.0775,
#   'valence': 0.761,
#   'tempo': 88.018,
#   'type': 'audio_features',
#   'id': '72HvecffhEOZ6Og0T0pXF9',
#   'uri': 'spotify:track:72HvecffhEOZ6Og0T0pXF9',
#   'track_href': 'https://api.spotify.com/v1/tracks/72HvecffhEOZ6Og0T0pXF9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/72HvecffhEOZ6Og0T0pXF9',
#   'duration_ms': 190440,
#   'time_signature': 4},
#  {'danceability': 0.783,
#   'energy': 0.84,
#   'key': 1,
#   'loudness': -3.416,
#   'mode': 1,
#   'speechiness': 0.051,
#   'acousticness': 0.174,
#   'instrumentalness': 0,
#   'liveness': 0.412,
#   'valence': 0.838,
#   'tempo': 95.002,
#   'type': 'audio_features',
#   'id': '43cIgYzLFEkBZHC6jt0Lt7',
#   'uri': 'spotify:track:43cIgYzLFEkBZHC6jt0Lt7',
#   'track_href': 'https://api.spotify.com/v1/tracks/43cIgYzLFEkBZHC6jt0Lt7',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/43cIgYzLFEkBZHC6jt0Lt7',
#   'duration_ms': 200480,
#   'time_signature': 4},
#  {'danceability': 0.85,
#   'energy': 0.854,
#   'key': 0,
#   'loudness': -5.157,
#   'mode': 1,
#   'speechiness': 0.0561,
#   'acousticness': 0.388,
#   'instrumentalness': 3.7e-06,
#   'liveness': 0.0692,
#   'valence': 0.758,
#   'tempo': 96.009,
#   'type': 'audio_features',
#   'id': '7JEqtD0YdBccQRpLyKEJFd',
#   'uri': 'spotify:track:7JEqtD0YdBccQRpLyKEJFd',
#   'track_href': 'https://api.spotify.com/v1/tracks/7JEqtD0YdBccQRpLyKEJFd',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7JEqtD0YdBccQRpLyKEJFd',
#   'duration_ms': 192574,
#   'time_signature': 4},
#  {'danceability': 0.687,
#   'energy': 0.806,
#   'key': 1,
#   'loudness': -6.019,
#   'mode': 0,
#   'speechiness': 0.0549,
#   'acousticness': 0.0358,
#   'instrumentalness': 5.83e-06,
#   'liveness': 0.0569,
#   'valence': 0.534,
#   'tempo': 176.064,
#   'type': 'audio_features',
#   'id': '5WHUrJ8LnzFrc8FXXT4GZL',
#   'uri': 'spotify:track:5WHUrJ8LnzFrc8FXXT4GZL',
#   'track_href': 'https://api.spotify.com/v1/tracks/5WHUrJ8LnzFrc8FXXT4GZL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5WHUrJ8LnzFrc8FXXT4GZL',
#   'duration_ms': 189040,
#   'time_signature': 4},
#  {'danceability': 0.783,
#   'energy': 0.84,
#   'key': 1,
#   'loudness': -3.416,
#   'mode': 1,
#   'speechiness': 0.051,
#   'acousticness': 0.174,
#   'instrumentalness': 0,
#   'liveness': 0.412,
#   'valence': 0.838,
#   'tempo': 95.002,
#   'type': 'audio_features',
#   'id': '7w7Cruh98cr5izeNe2wZkT',
#   'uri': 'spotify:track:7w7Cruh98cr5izeNe2wZkT',
#   'track_href': 'https://api.spotify.com/v1/tracks/7w7Cruh98cr5izeNe2wZkT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7w7Cruh98cr5izeNe2wZkT',
#   'duration_ms': 200480,
#   'time_signature': 4},
#  {'danceability': 0.85,
#   'energy': 0.854,
#   'key': 0,
#   'loudness': -5.157,
#   'mode': 1,
#   'speechiness': 0.0561,
#   'acousticness': 0.388,
#   'instrumentalness': 3.7e-06,
#   'liveness': 0.0692,
#   'valence': 0.758,
#   'tempo': 96.009,
#   'type': 'audio_features',
#   'id': '1ZBCtiAfIZU4pv8qe5gPow',
#   'uri': 'spotify:track:1ZBCtiAfIZU4pv8qe5gPow',
#   'track_href': 'https://api.spotify.com/v1/tracks/1ZBCtiAfIZU4pv8qe5gPow',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1ZBCtiAfIZU4pv8qe5gPow',
#   'duration_ms': 192574,
#   'time_signature': 4},
#  {'danceability': 0.659,
#   'energy': 0.901,
#   'key': 7,
#   'loudness': -2.814,
#   'mode': 1,
#   'speechiness': 0.0358,
#   'acousticness': 0.0478,
#   'instrumentalness': 0,
#   'liveness': 0.148,
#   'valence': 0.704,
#   'tempo': 93.979,
#   'type': 'audio_features',
#   'id': '1h9YqIVjCpHyrDJjaJyfDd',
#   'uri': 'spotify:track:1h9YqIVjCpHyrDJjaJyfDd',
#   'track_href': 'https://api.spotify.com/v1/tracks/1h9YqIVjCpHyrDJjaJyfDd',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1h9YqIVjCpHyrDJjaJyfDd',
#   'duration_ms': 210520,
#   'time_signature': 4},
#  {'danceability': 0.687,
#   'energy': 0.806,
#   'key': 1,
#   'loudness': -6.019,
#   'mode': 0,
#   'speechiness': 0.0549,
#   'acousticness': 0.0358,
#   'instrumentalness': 5.83e-06,
#   'liveness': 0.0569,
#   'valence': 0.534,
#   'tempo': 176.064,
#   'type': 'audio_features',
#   'id': '2u0XzPGeROGLz21n9Cw3zh',
#   'uri': 'spotify:track:2u0XzPGeROGLz21n9Cw3zh',
#   'track_href': 'https://api.spotify.com/v1/tracks/2u0XzPGeROGLz21n9Cw3zh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2u0XzPGeROGLz21n9Cw3zh',
#   'duration_ms': 189040,
#   'time_signature': 4},
#  {'danceability': 0.655,
#   'energy': 0.879,
#   'key': 0,
#   'loudness': -4.743,
#   'mode': 1,
#   'speechiness': 0.235,
#   'acousticness': 0.0321,
#   'instrumentalness': 6.97e-06,
#   'liveness': 0.0679,
#   'valence': 0.657,
#   'tempo': 184.027,
#   'type': 'audio_features',
#   'id': '5pmgHhXKSc3pePUf5tt6My',
#   'uri': 'spotify:track:5pmgHhXKSc3pePUf5tt6My',
#   'track_href': 'https://api.spotify.com/v1/tracks/5pmgHhXKSc3pePUf5tt6My',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5pmgHhXKSc3pePUf5tt6My',
#   'duration_ms': 213000,
#   'time_signature': 4},
#  {'danceability': 0.687,
#   'energy': 0.806,
#   'key': 1,
#   'loudness': -6.019,
#   'mode': 0,
#   'speechiness': 0.0549,
#   'acousticness': 0.0358,
#   'instrumentalness': 5.83e-06,
#   'liveness': 0.0569,
#   'valence': 0.534,
#   'tempo': 176.064,
#   'type': 'audio_features',
#   'id': '5CgWwxjmb9UH2i2gmEMYOl',
#   'uri': 'spotify:track:5CgWwxjmb9UH2i2gmEMYOl',
#   'track_href': 'https://api.spotify.com/v1/tracks/5CgWwxjmb9UH2i2gmEMYOl',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5CgWwxjmb9UH2i2gmEMYOl',
#   'duration_ms': 189040,
#   'time_signature': 4},
#  {'danceability': 0.846,
#   'energy': 0.842,
#   'key': 8,
#   'loudness': -4.066,
#   'mode': 1,
#   'speechiness': 0.0783,
#   'acousticness': 0.23,
#   'instrumentalness': 6.88e-06,
#   'liveness': 0.174,
#   'valence': 0.762,
#   'tempo': 93.962,
#   'type': 'audio_features',
#   'id': '5JEleltBwQkAAY5Jaog8r1',
#   'uri': 'spotify:track:5JEleltBwQkAAY5Jaog8r1',
#   'track_href': 'https://api.spotify.com/v1/tracks/5JEleltBwQkAAY5Jaog8r1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5JEleltBwQkAAY5Jaog8r1',
#   'duration_ms': 178800,
#   'time_signature': 4},
#  {'danceability': 0.805,
#   'energy': 0.878,
#   'key': 7,
#   'loudness': -3.826,
#   'mode': 1,
#   'speechiness': 0.0864,
#   'acousticness': 0.0754,
#   'instrumentalness': 0.00329,
#   'liveness': 0.0656,
#   'valence': 0.922,
#   'tempo': 124.994,
#   'type': 'audio_features',
#   'id': '5JzyJsikH4fe1uRk45pNRR',
#   'uri': 'spotify:track:5JzyJsikH4fe1uRk45pNRR',
#   'track_href': 'https://api.spotify.com/v1/tracks/5JzyJsikH4fe1uRk45pNRR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5JzyJsikH4fe1uRk45pNRR',
#   'duration_ms': 224800,
#   'time_signature': 4},
#  {'danceability': 0.659,
#   'energy': 0.901,
#   'key': 7,
#   'loudness': -2.814,
#   'mode': 1,
#   'speechiness': 0.0358,
#   'acousticness': 0.0478,
#   'instrumentalness': 0,
#   'liveness': 0.148,
#   'valence': 0.704,
#   'tempo': 93.979,
#   'type': 'audio_features',
#   'id': '5OMjNIYDLP6UyrpWTSGThv',
#   'uri': 'spotify:track:5OMjNIYDLP6UyrpWTSGThv',
#   'track_href': 'https://api.spotify.com/v1/tracks/5OMjNIYDLP6UyrpWTSGThv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5OMjNIYDLP6UyrpWTSGThv',
#   'duration_ms': 210520,
#   'time_signature': 4},
#  {'danceability': 0.659,
#   'energy': 0.901,
#   'key': 7,
#   'loudness': -2.814,
#   'mode': 1,
#   'speechiness': 0.0358,
#   'acousticness': 0.0478,
#   'instrumentalness': 0,
#   'liveness': 0.148,
#   'valence': 0.704,
#   'tempo': 93.979,
#   'type': 'audio_features',
#   'id': '1wMqGYkAl7HGjKN65J33z4',
#   'uri': 'spotify:track:1wMqGYkAl7HGjKN65J33z4',
#   'track_href': 'https://api.spotify.com/v1/tracks/1wMqGYkAl7HGjKN65J33z4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1wMqGYkAl7HGjKN65J33z4',
#   'duration_ms': 210520,
#   'time_signature': 4},
#  {'danceability': 0.757,
#   'energy': 0.84,
#   'key': 10,
#   'loudness': -5.363,
#   'mode': 0,
#   'speechiness': 0.0651,
#   'acousticness': 0.334,
#   'instrumentalness': 0,
#   'liveness': 0.224,
#   'valence': 0.824,
#   'tempo': 91.976,
#   'type': 'audio_features',
#   'id': '2u4E1VoERWK6ogaWoD5HU6',
#   'uri': 'spotify:track:2u4E1VoERWK6ogaWoD5HU6',
#   'track_href': 'https://api.spotify.com/v1/tracks/2u4E1VoERWK6ogaWoD5HU6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2u4E1VoERWK6ogaWoD5HU6',
#   'duration_ms': 204200,
#   'time_signature': 4},
#  {'danceability': 0.687,
#   'energy': 0.806,
#   'key': 1,
#   'loudness': -6.019,
#   'mode': 0,
#   'speechiness': 0.0549,
#   'acousticness': 0.0358,
#   'instrumentalness': 5.83e-06,
#   'liveness': 0.0569,
#   'valence': 0.534,
#   'tempo': 176.064,
#   'type': 'audio_features',
#   'id': '1lbWGsRP8LqrlByjsmPoFx',
#   'uri': 'spotify:track:1lbWGsRP8LqrlByjsmPoFx',
#   'track_href': 'https://api.spotify.com/v1/tracks/1lbWGsRP8LqrlByjsmPoFx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1lbWGsRP8LqrlByjsmPoFx',
#   'duration_ms': 189040,
#   'time_signature': 4},
#  {'danceability': 0.85,
#   'energy': 0.854,
#   'key': 0,
#   'loudness': -5.157,
#   'mode': 1,
#   'speechiness': 0.0561,
#   'acousticness': 0.388,
#   'instrumentalness': 3.7e-06,
#   'liveness': 0.0692,
#   'valence': 0.758,
#   'tempo': 96.009,
#   'type': 'audio_features',
#   'id': '2Y9bPO7z34V3xp2w3WDCQd',
#   'uri': 'spotify:track:2Y9bPO7z34V3xp2w3WDCQd',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Y9bPO7z34V3xp2w3WDCQd',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Y9bPO7z34V3xp2w3WDCQd',
#   'duration_ms': 192574,
#   'time_signature': 4},
#  {'danceability': 0.687,
#   'energy': 0.806,
#   'key': 1,
#   'loudness': -6.019,
#   'mode': 0,
#   'speechiness': 0.0549,
#   'acousticness': 0.0358,
#   'instrumentalness': 5.83e-06,
#   'liveness': 0.0569,
#   'valence': 0.534,
#   'tempo': 176.064,
#   'type': 'audio_features',
#   'id': '5YsZxaD7KTBfxFoGCNlHkA',
#   'uri': 'spotify:track:5YsZxaD7KTBfxFoGCNlHkA',
#   'track_href': 'https://api.spotify.com/v1/tracks/5YsZxaD7KTBfxFoGCNlHkA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5YsZxaD7KTBfxFoGCNlHkA',
#   'duration_ms': 189040,
#   'time_signature': 4},
#  {'danceability': 0.659,
#   'energy': 0.901,
#   'key': 7,
#   'loudness': -2.814,
#   'mode': 1,
#   'speechiness': 0.0358,
#   'acousticness': 0.0478,
#   'instrumentalness': 0,
#   'liveness': 0.148,
#   'valence': 0.704,
#   'tempo': 93.979,
#   'type': 'audio_features',
#   'id': '0iFROFTyditGLmb4CtqMBb',
#   'uri': 'spotify:track:0iFROFTyditGLmb4CtqMBb',
#   'track_href': 'https://api.spotify.com/v1/tracks/0iFROFTyditGLmb4CtqMBb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0iFROFTyditGLmb4CtqMBb',
#   'duration_ms': 210520,
#   'time_signature': 4},
#  {'danceability': 0.735,
#   'energy': 0.906,
#   'key': 10,
#   'loudness': -3.658,
#   'mode': 0,
#   'speechiness': 0.11,
#   'acousticness': 0.0342,
#   'instrumentalness': 0,
#   'liveness': 0.292,
#   'valence': 0.71,
#   'tempo': 92.023,
#   'type': 'audio_features',
#   'id': '13dOhN3ZhJeLn3lVYtlk5k',
#   'uri': 'spotify:track:13dOhN3ZhJeLn3lVYtlk5k',
#   'track_href': 'https://api.spotify.com/v1/tracks/13dOhN3ZhJeLn3lVYtlk5k',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/13dOhN3ZhJeLn3lVYtlk5k',
#   'duration_ms': 190000,
#   'time_signature': 4},
#  {'danceability': 0.846,
#   'energy': 0.842,
#   'key': 8,
#   'loudness': -4.066,
#   'mode': 1,
#   'speechiness': 0.0783,
#   'acousticness': 0.23,
#   'instrumentalness': 6.88e-06,
#   'liveness': 0.174,
#   'valence': 0.762,
#   'tempo': 93.962,
#   'type': 'audio_features',
#   'id': '1iY1JrQQqCHGJKNlNFrGT0',
#   'uri': 'spotify:track:1iY1JrQQqCHGJKNlNFrGT0',
#   'track_href': 'https://api.spotify.com/v1/tracks/1iY1JrQQqCHGJKNlNFrGT0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1iY1JrQQqCHGJKNlNFrGT0',
#   'duration_ms': 178800,
#   'time_signature': 4},
# ...
#   'key': 0,
#   'loudness': -4.782,
#   'mode': 1,
#   'speechiness': 0.23,
#   'acousticness': 0.0291,
#   'instrumentalness': 2.78e-05,
#   'liveness': 0.0639,
#   'valence': 0.689,
#   'tempo': 184.058,
#   'type': 'audio_features',
#   'id': '5B24L6KVFrdjU9iDbYZXeY',
#   'uri': 'spotify:track:5B24L6KVFrdjU9iDbYZXeY',
#   'track_href': 'https://api.spotify.com/v1/tracks/5B24L6KVFrdjU9iDbYZXeY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5B24L6KVFrdjU9iDbYZXeY',
#   'duration_ms': 212987,
#   'time_signature': 4},
#  {'danceability': 0.639,
#   'energy': 0.943,
#   'key': 5,
#   'loudness': -3.542,
#   'mode': 1,
#   'speechiness': 0.136,
#   'acousticness': 0.0462,
#   'instrumentalness': 0,
#   'liveness': 0.141,
#   'valence': 0.639,
#   'tempo': 198.051,
#   'type': 'audio_features',
#   'id': '0WWJOn0kVv90TyyStHisD3',
#   'uri': 'spotify:track:0WWJOn0kVv90TyyStHisD3',
#   'track_href': 'https://api.spotify.com/v1/tracks/0WWJOn0kVv90TyyStHisD3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0WWJOn0kVv90TyyStHisD3',
#   'duration_ms': 197053,
#   'time_signature': 4},
#  {'danceability': 0.737,
#   'energy': 0.86,
#   'key': 8,
#   'loudness': -2.652,
#   'mode': 0,
#   'speechiness': 0.0594,
#   'acousticness': 0.11,
#   'instrumentalness': 1.94e-06,
#   'liveness': 0.0574,
#   'valence': 0.656,
#   'tempo': 93.989,
#   'type': 'audio_features',
#   'id': '3MQHI1XeHd8CaUibAhOeMU',
#   'uri': 'spotify:track:3MQHI1XeHd8CaUibAhOeMU',
#   'track_href': 'https://api.spotify.com/v1/tracks/3MQHI1XeHd8CaUibAhOeMU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3MQHI1XeHd8CaUibAhOeMU',
#   'duration_ms': 193227,
#   'time_signature': 4},
#  {'danceability': 0.687,
#   'energy': 0.806,
#   'key': 1,
#   'loudness': -6.019,
#   'mode': 0,
#   'speechiness': 0.0549,
#   'acousticness': 0.0358,
#   'instrumentalness': 5.83e-06,
#   'liveness': 0.0569,
#   'valence': 0.534,
#   'tempo': 176.064,
#   'type': 'audio_features',
#   'id': '6a2L0OxZtz2JV8aFkw8IiZ',
#   'uri': 'spotify:track:6a2L0OxZtz2JV8aFkw8IiZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/6a2L0OxZtz2JV8aFkw8IiZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6a2L0OxZtz2JV8aFkw8IiZ',
#   'duration_ms': 189040,
#   'time_signature': 4},
#  {'danceability': 0.707,
#   'energy': 0.475,
#   'key': 2,
#   'loudness': -9.192,
#   'mode': 0,
#   'speechiness': 0.346,
#   'acousticness': 0.329,
#   'instrumentalness': 0,
#   'liveness': 0.256,
#   'valence': 0.845,
#   'tempo': 98.558,
#   'type': 'audio_features',
#   'id': '05PByxfz5DQq3rf4WHfCGT',
#   'uri': 'spotify:track:05PByxfz5DQq3rf4WHfCGT',
#   'track_href': 'https://api.spotify.com/v1/tracks/05PByxfz5DQq3rf4WHfCGT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/05PByxfz5DQq3rf4WHfCGT',
#   'duration_ms': 59467,
#   'time_signature': 4},
#  {'danceability': 0.737,
#   'energy': 0.86,
#   'key': 8,
#   'loudness': -2.652,
#   'mode': 0,
#   'speechiness': 0.0594,
#   'acousticness': 0.11,
#   'instrumentalness': 1.94e-06,
#   'liveness': 0.0574,
#   'valence': 0.656,
#   'tempo': 93.989,
#   'type': 'audio_features',
#   'id': '08AzR5KJidfi1LlZ6FpPUD',
#   'uri': 'spotify:track:08AzR5KJidfi1LlZ6FpPUD',
#   'track_href': 'https://api.spotify.com/v1/tracks/08AzR5KJidfi1LlZ6FpPUD',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/08AzR5KJidfi1LlZ6FpPUD',
#   'duration_ms': 193227,
#   'time_signature': 4},
#  {'danceability': 0.899,
#   'energy': 0.626,
#   'key': 6,
#   'loudness': -4.228,
#   'mode': 0,
#   'speechiness': 0.292,
#   'acousticness': 0.076,
#   'instrumentalness': 0,
#   'liveness': 0.0631,
#   'valence': 0.873,
#   'tempo': 88.007,
#   'type': 'audio_features',
#   'id': '4KCAVQhpdSIGo8n44HdLNU',
#   'uri': 'spotify:track:4KCAVQhpdSIGo8n44HdLNU',
#   'track_href': 'https://api.spotify.com/v1/tracks/4KCAVQhpdSIGo8n44HdLNU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4KCAVQhpdSIGo8n44HdLNU',
#   'duration_ms': 234320,
#   'time_signature': 4},
#  {'danceability': 0.85,
#   'energy': 0.854,
#   'key': 0,
#   'loudness': -5.157,
#   'mode': 1,
#   'speechiness': 0.0561,
#   'acousticness': 0.388,
#   'instrumentalness': 3.7e-06,
#   'liveness': 0.0692,
#   'valence': 0.758,
#   'tempo': 96.009,
#   'type': 'audio_features',
#   'id': '5WP2dzV9FtskU3VryB3MGk',
#   'uri': 'spotify:track:5WP2dzV9FtskU3VryB3MGk',
#   'track_href': 'https://api.spotify.com/v1/tracks/5WP2dzV9FtskU3VryB3MGk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5WP2dzV9FtskU3VryB3MGk',
#   'duration_ms': 192574,
#   'time_signature': 4},
#  {'danceability': 0.691,
#   'energy': 0.894,
#   'key': 9,
#   'loudness': -1.681,
#   'mode': 0,
#   'speechiness': 0.115,
#   'acousticness': 0.291,
#   'instrumentalness': 0,
#   'liveness': 0.104,
#   'valence': 0.623,
#   'tempo': 184.018,
#   'type': 'audio_features',
#   'id': '08H5tfbhunOiVFV492eibn',
#   'uri': 'spotify:track:08H5tfbhunOiVFV492eibn',
#   'track_href': 'https://api.spotify.com/v1/tracks/08H5tfbhunOiVFV492eibn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/08H5tfbhunOiVFV492eibn',
#   'duration_ms': 241880,
#   'time_signature': 4},
#  {'danceability': 0.687,
#   'energy': 0.806,
#   'key': 1,
#   'loudness': -6.019,
#   'mode': 0,
#   'speechiness': 0.0549,
#   'acousticness': 0.0358,
#   'instrumentalness': 5.83e-06,
#   'liveness': 0.0569,
#   'valence': 0.534,
#   'tempo': 176.064,
#   'type': 'audio_features',
#   'id': '3AuAjPjtvc7AKFMMiXxlVe',
#   'uri': 'spotify:track:3AuAjPjtvc7AKFMMiXxlVe',
#   'track_href': 'https://api.spotify.com/v1/tracks/3AuAjPjtvc7AKFMMiXxlVe',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3AuAjPjtvc7AKFMMiXxlVe',
#   'duration_ms': 189040,
#   'time_signature': 4},
#  {'danceability': 0.863,
#   'energy': 0.781,
#   'key': 0,
#   'loudness': -6.274,
#   'mode': 1,
#   'speechiness': 0.0626,
#   'acousticness': 0.281,
#   'instrumentalness': 0,
#   'liveness': 0.0806,
#   'valence': 0.814,
#   'tempo': 96.002,
#   'type': 'audio_features',
#   'id': '4Vldea3w91g7aLHtKuCA9y',
#   'uri': 'spotify:track:4Vldea3w91g7aLHtKuCA9y',
#   'track_href': 'https://api.spotify.com/v1/tracks/4Vldea3w91g7aLHtKuCA9y',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4Vldea3w91g7aLHtKuCA9y',
#   'duration_ms': 172867,
#   'time_signature': 4},
#  {'danceability': 0.687,
#   'energy': 0.806,
#   'key': 1,
#   'loudness': -6.019,
#   'mode': 0,
#   'speechiness': 0.0549,
#   'acousticness': 0.0358,
#   'instrumentalness': 5.83e-06,
#   'liveness': 0.0569,
#   'valence': 0.534,
#   'tempo': 176.064,
#   'type': 'audio_features',
#   'id': '5mhuGmRvPBI5oTBM7B7dnn',
#   'uri': 'spotify:track:5mhuGmRvPBI5oTBM7B7dnn',
#   'track_href': 'https://api.spotify.com/v1/tracks/5mhuGmRvPBI5oTBM7B7dnn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5mhuGmRvPBI5oTBM7B7dnn',
#   'duration_ms': 189040,
#   'time_signature': 4},
#  {'danceability': 0.638,
#   'energy': 0.864,
#   'key': 1,
#   'loudness': -2.852,
#   'mode': 1,
#   'speechiness': 0.0649,
#   'acousticness': 0.121,
#   'instrumentalness': 0,
#   'liveness': 0.0469,
#   'valence': 0.685,
#   'tempo': 93.299,
#   'type': 'audio_features',
#   'id': '1qydEb1TNALGYq7CqJD8RP',
#   'uri': 'spotify:track:1qydEb1TNALGYq7CqJD8RP',
#   'track_href': 'https://api.spotify.com/v1/tracks/1qydEb1TNALGYq7CqJD8RP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1qydEb1TNALGYq7CqJD8RP',
#   'duration_ms': 193360,
#   'time_signature': 4},
#  {'danceability': 0.638,
#   'energy': 0.864,
#   'key': 1,
#   'loudness': -2.852,
#   'mode': 1,
#   'speechiness': 0.065,
#   'acousticness': 0.121,
#   'instrumentalness': 0,
#   'liveness': 0.0469,
#   'valence': 0.685,
#   'tempo': 93.296,
#   'type': 'audio_features',
#   'id': '3tBwb4E7sVr141amSxmc2p',
#   'uri': 'spotify:track:3tBwb4E7sVr141amSxmc2p',
#   'track_href': 'https://api.spotify.com/v1/tracks/3tBwb4E7sVr141amSxmc2p',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3tBwb4E7sVr141amSxmc2p',
#   'duration_ms': 193360,
#   'time_signature': 4},
#  {'danceability': 0.734,
#   'energy': 0.531,
#   'key': 1,
#   'loudness': -5.662,
#   'mode': 1,
#   'speechiness': 0.0321,
#   'acousticness': 0.196,
#   'instrumentalness': 0,
#   'liveness': 0.119,
#   'valence': 0.199,
#   'tempo': 130.025,
#   'type': 'audio_features',
#   'id': '4vAhGoUUPIfCqR1BCIzr7M',
#   'uri': 'spotify:track:4vAhGoUUPIfCqR1BCIzr7M',
#   'track_href': 'https://api.spotify.com/v1/tracks/4vAhGoUUPIfCqR1BCIzr7M',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4vAhGoUUPIfCqR1BCIzr7M',
#   'duration_ms': 279613,
#   'time_signature': 4},
#  {'danceability': 0.687,
#   'energy': 0.806,
#   'key': 1,
#   'loudness': -6.019,
#   'mode': 0,
#   'speechiness': 0.0549,
#   'acousticness': 0.0358,
#   'instrumentalness': 5.83e-06,
#   'liveness': 0.0569,
#   'valence': 0.534,
#   'tempo': 176.064,
#   'type': 'audio_features',
#   'id': '4THzRdd4knMfCnX0G8rMYz',
#   'uri': 'spotify:track:4THzRdd4knMfCnX0G8rMYz',
#   'track_href': 'https://api.spotify.com/v1/tracks/4THzRdd4knMfCnX0G8rMYz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4THzRdd4knMfCnX0G8rMYz',
#   'duration_ms': 189040,
#   'time_signature': 4},
#  {'danceability': 0.686,
#   'energy': 0.859,
#   'key': 5,
#   'loudness': -2.595,
#   'mode': 0,
#   'speechiness': 0.0553,
#   'acousticness': 0.118,
#   'instrumentalness': 0,
#   'liveness': 0.317,
#   'valence': 0.891,
#   'tempo': 176.018,
#   'type': 'audio_features',
#   'id': '5jzELHsk9LVrR8QTnrfs0Z',
#   'uri': 'spotify:track:5jzELHsk9LVrR8QTnrfs0Z',
#   'track_href': 'https://api.spotify.com/v1/tracks/5jzELHsk9LVrR8QTnrfs0Z',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5jzELHsk9LVrR8QTnrfs0Z',
#   'duration_ms': 204520,
#   'time_signature': 4},
#  {'danceability': 0.773,
#   'energy': 0.8,
#   'key': 1,
#   'loudness': -3.015,
#   'mode': 1,
#   'speechiness': 0.0465,
#   'acousticness': 0.212,
#   'instrumentalness': 0,
#   'liveness': 0.437,
#   'valence': 0.849,
#   'tempo': 94.993,
#   'type': 'audio_features',
#   'id': '6nR4ZCrJ3j9oKjhrfdDg1O',
#   'uri': 'spotify:track:6nR4ZCrJ3j9oKjhrfdDg1O',
#   'track_href': 'https://api.spotify.com/v1/tracks/6nR4ZCrJ3j9oKjhrfdDg1O',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6nR4ZCrJ3j9oKjhrfdDg1O',
#   'duration_ms': 244160,
#   'time_signature': 4},
#  {'danceability': 0.764,
#   'energy': 0.0146,
#   'key': 8,
#   'loudness': -32.947,
#   'mode': 0,
#   'speechiness': 0.0506,
#   'acousticness': 0.986,
#   'instrumentalness': 0.942,
#   'liveness': 0.0965,
#   'valence': 0.385,
#   'tempo': 124.015,
#   'type': 'audio_features',
#   'id': '7Bk0FfIcCQFhqPyXL5ked1',
#   'uri': 'spotify:track:7Bk0FfIcCQFhqPyXL5ked1',
#   'track_href': 'https://api.spotify.com/v1/tracks/7Bk0FfIcCQFhqPyXL5ked1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7Bk0FfIcCQFhqPyXL5ked1',
#   'duration_ms': 349355,
#   'time_signature': 5},
#  {'danceability': 0.783,
#   'energy': 0.84,
#   'key': 1,
#   'loudness': -3.416,
#   'mode': 1,
#   'speechiness': 0.051,
#   'acousticness': 0.174,
#   'instrumentalness': 0,
#   'liveness': 0.412,
#   'valence': 0.838,
#   'tempo': 95.002,
#   'type': 'audio_features',
#   'id': '17Ziicyy7hHhMZcCX5vmBa',
#   'uri': 'spotify:track:17Ziicyy7hHhMZcCX5vmBa',
#   'track_href': 'https://api.spotify.com/v1/tracks/17Ziicyy7hHhMZcCX5vmBa',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/17Ziicyy7hHhMZcCX5vmBa',
#   'duration_ms': 200480,
#   'time_signature': 4},
#  {'danceability': 0.687,
#   'energy': 0.806,
#   'key': 1,
#   'loudness': -6.019,
#   'mode': 0,
#   'speechiness': 0.0549,
#   'acousticness': 0.0358,
#   'instrumentalness': 5.83e-06,
#   'liveness': 0.0569,
#   'valence': 0.534,
#   'tempo': 176.064,
#   'type': 'audio_features',
#   'id': '6ysj3ItTe6sm3f9bkTNkdA',
#   'uri': 'spotify:track:6ysj3ItTe6sm3f9bkTNkdA',
#   'track_href': 'https://api.spotify.com/v1/tracks/6ysj3ItTe6sm3f9bkTNkdA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6ysj3ItTe6sm3f9bkTNkdA',
#   'duration_ms': 189040,
#   'time_signature': 4},
#  {'danceability': 0.737,
#   'energy': 0.86,
#   'key': 8,
#   'loudness': -2.652,
#   'mode': 0,
#   'speechiness': 0.0594,
#   'acousticness': 0.11,
#   'instrumentalness': 1.94e-06,
#   'liveness': 0.0574,
#   'valence': 0.656,
#   'tempo': 93.989,
#   'type': 'audio_features',
#   'id': '752VGTh6DzrgC6rmnO7EEz',
#   'uri': 'spotify:track:752VGTh6DzrgC6rmnO7EEz',
#   'track_href': 'https://api.spotify.com/v1/tracks/752VGTh6DzrgC6rmnO7EEz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/752VGTh6DzrgC6rmnO7EEz',
#   'duration_ms': 193227,
#   'time_signature': 4},
#  {'danceability': 0.687,
#   'energy': 0.806,
#   'key': 1,
#   'loudness': -6.019,
#   'mode': 0,
#   'speechiness': 0.0549,
#   'acousticness': 0.0358,
#   'instrumentalness': 5.83e-06,
#   'liveness': 0.0569,
#   'valence': 0.534,
#   'tempo': 176.064,
#   'type': 'audio_features',
#   'id': '129QgvFGnBV7AhqeKtA0Gl',
#   'uri': 'spotify:track:129QgvFGnBV7AhqeKtA0Gl',
#   'track_href': 'https://api.spotify.com/v1/tracks/129QgvFGnBV7AhqeKtA0Gl',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/129QgvFGnBV7AhqeKtA0Gl',
#   'duration_ms': 189040,
#   'time_signature': 4},
#  {'danceability': 0.737,
#   'energy': 0.86,
#   'key': 8,
#   'loudness': -2.652,
#   'mode': 0,
#   'speechiness': 0.0594,
#   'acousticness': 0.11,
#   'instrumentalness': 1.94e-06,
#   'liveness': 0.0574,
#   'valence': 0.656,
#   'tempo': 93.989,
#   'type': 'audio_features',
#   'id': '3WWGC4gH4pMbPGrbDpwUHO',
#   'uri': 'spotify:track:3WWGC4gH4pMbPGrbDpwUHO',
#   'track_href': 'https://api.spotify.com/v1/tracks/3WWGC4gH4pMbPGrbDpwUHO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3WWGC4gH4pMbPGrbDpwUHO',
#   'duration_ms': 193227,
#   'time_signature': 4},
#  {'danceability': 0.737,
#   'energy': 0.86,
#   'key': 8,
#   'loudness': -2.652,
#   'mode': 0,
#   'speechiness': 0.0594,
#   'acousticness': 0.11,
#   'instrumentalness': 1.94e-06,
#   'liveness': 0.0574,
#   'valence': 0.656,
#   'tempo': 93.989,
#   'type': 'audio_features',
#   'id': '7Aa0paeoPI5QiPzELC6Q3q',
#   'uri': 'spotify:track:7Aa0paeoPI5QiPzELC6Q3q',
#   'track_href': 'https://api.spotify.com/v1/tracks/7Aa0paeoPI5QiPzELC6Q3q',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7Aa0paeoPI5QiPzELC6Q3q',
#   'duration_ms': 193227,
#   'time_signature': 4},
#  {'danceability': 0.73,
#   'energy': 0.939,
#   'key': 11,
#   'loudness': -4.665,
#   'mode': 0,
#   'speechiness': 0.0532,
#   'acousticness': 0.0347,
#   'instrumentalness': 0,
#   'liveness': 0.335,
#   'valence': 0.939,
#   'tempo': 121.001,
#   'type': 'audio_features',
#   'id': '1OnHrkXRnx731AYCKtd42a',
#   'uri': 'spotify:track:1OnHrkXRnx731AYCKtd42a',
#   'track_href': 'https://api.spotify.com/v1/tracks/1OnHrkXRnx731AYCKtd42a',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1OnHrkXRnx731AYCKtd42a',
#   'duration_ms': 218520,
#   'time_signature': 4},
#  {'danceability': 0.687,
#   'energy': 0.806,
#   'key': 1,
#   'loudness': -6.019,
#   'mode': 0,
#   'speechiness': 0.0549,
#   'acousticness': 0.0358,
#   'instrumentalness': 5.83e-06,
#   'liveness': 0.0569,
#   'valence': 0.534,
#   'tempo': 176.064,
#   'type': 'audio_features',
#   'id': '4X8eM7ta9mAivBZIhxSrk5',
#   'uri': 'spotify:track:4X8eM7ta9mAivBZIhxSrk5',
#   'track_href': 'https://api.spotify.com/v1/tracks/4X8eM7ta9mAivBZIhxSrk5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4X8eM7ta9mAivBZIhxSrk5',
#   'duration_ms': 189040,
#   'time_signature': 4},
#  {'danceability': 0.721,
#   'energy': 0.00994,
#   'key': 0,
#   'loudness': -32.554,
#   'mode': 1,
#   'speechiness': 0.046,
#   'acousticness': 0.992,
#   'instrumentalness': 0.95,
#   'liveness': 0.0779,
#   'valence': 0.0937,
#   'tempo': 123.973,
#   'type': 'audio_features',
#   'id': '04QZrxov1SgJZR4W5ejFka',
#   'uri': 'spotify:track:04QZrxov1SgJZR4W5ejFka',
#   'track_href': 'https://api.spotify.com/v1/tracks/04QZrxov1SgJZR4W5ejFka',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/04QZrxov1SgJZR4W5ejFka',
#   'duration_ms': 287419,
#   'time_signature': 4},
#  {'danceability': 0.796,
#   'energy': 0.872,
#   'key': 9,
#   'loudness': -2.779,
#   'mode': 0,
#   'speechiness': 0.111,
#   'acousticness': 0.0468,
#   'instrumentalness': 0.000583,
#   'liveness': 0.0649,
#   'valence': 0.727,
#   'tempo': 105.995,
#   'type': 'audio_features',
#   'id': '14Jin3Y73LJHXXnEpP4wUm',
#   'uri': 'spotify:track:14Jin3Y73LJHXXnEpP4wUm',
#   'track_href': 'https://api.spotify.com/v1/tracks/14Jin3Y73LJHXXnEpP4wUm',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/14Jin3Y73LJHXXnEpP4wUm',
#   'duration_ms': 239619,
#   'time_signature': 4},
#  ...]

# %%
d = uris[0]

# %%
pd.DataFrame(uris)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-a3ad91127bfc> in <module>
# ----> 1 pd.DataFrame(uris)
#
# /usr/local/Cellar/jupyterlab/3.0.9/libexec/lib/python3.9/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     568                     if is_named_tuple(data[0]) and columns is None:
#     569                         columns = data[0]._fields
# --> 570                     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     571                     columns = ensure_index(columns)
#     572
#
# /usr/local/Cellar/jupyterlab/3.0.9/libexec/lib/python3.9/site-packages/pandas/core/internals/construction.py in to_arrays(data, columns, coerce_float, dtype)
#     528         return _list_to_arrays(data, columns, coerce_float=coerce_float, dtype=dtype)
#     529     elif isinstance(data[0], abc.Mapping):
# --> 530         return _list_of_dict_to_arrays(
#     531             data, columns, coerce_float=coerce_float, dtype=dtype
#     532         )
#
# /usr/local/Cellar/jupyterlab/3.0.9/libexec/lib/python3.9/site-packages/pandas/core/internals/construction.py in _list_of_dict_to_arrays(data, columns, coerce_float, dtype)
#     641         gen = (list(x.keys()) for x in data)
#     642         sort = not any(isinstance(d, dict) for d in data)
# --> 643         columns = lib.fast_unique_multiple_list_gen(gen, sort=sort)
#     644
#     645     # assure that they are of the base dict class and not of derived
#
# pandas/_libs/lib.pyx in pandas._libs.lib.fast_unique_multiple_list_gen()
#
# /usr/local/Cellar/jupyterlab/3.0.9/libexec/lib/python3.9/site-packages/pandas/core/internals/construction.py in <genexpr>(.0)
#     639     """
#     640     if columns is None:
# --> 641         gen = (list(x.keys()) for x in data)
#     642         sort = not any(isinstance(d, dict) for d in data)
#     643         columns = lib.fast_unique_multiple_list_gen(gen, sort=sort)
#
# AttributeError: 'NoneType' object has no attribute 'keys'

# %%
pd.DataFrame(uris[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-02388fc2a525> in <module>
# ----> 1 pd.DataFrame(uris[0])
#
# /usr/local/Cellar/jupyterlab/3.0.9/libexec/lib/python3.9/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# /usr/local/Cellar/jupyterlab/3.0.9/libexec/lib/python3.9/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# --> 287     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     288
#     289
#
# /usr/local/Cellar/jupyterlab/3.0.9/libexec/lib/python3.9/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      78         # figure out the index, if necessary
#      79         if index is None:
# ---> 80             index = extract_index(arrays)
#      81         else:
#      82             index = ensure_index(index)
#
# /usr/local/Cellar/jupyterlab/3.0.9/libexec/lib/python3.9/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     389
#     390         if not indexes and not raw_lengths:
# --> 391             raise ValueError("If using all scalar values, you must pass an index")
#     392
#     393         if have_series:
#
# ValueError: If using all scalar values, you must pass an index

# %%
    S = pd.DataFrame(songs_names)
    A = pd.DataFrame(artists_names)
    U = pd.DataFrame(uris)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-f532dda5565a> in <module>
#       1 S = pd.DataFrame(songs_names)
#       2 A = pd.DataFrame(artists_names)
# ----> 3 U = pd.DataFrame(uris)
#
# /usr/local/Cellar/jupyterlab/3.0.9/libexec/lib/python3.9/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     568                     if is_named_tuple(data[0]) and columns is None:
#     569                         columns = data[0]._fields
# --> 570                     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     571                     columns = ensure_index(columns)
#     572
#
# /usr/local/Cellar/jupyterlab/3.0.9/libexec/lib/python3.9/site-packages/pandas/core/internals/construction.py in to_arrays(data, columns, coerce_float, dtype)
#     528         return _list_to_arrays(data, columns, coerce_float=coerce_float, dtype=dtype)
#     529     elif isinstance(data[0], abc.Mapping):
# --> 530         return _list_of_dict_to_arrays(
#     531             data, columns, coerce_float=coerce_float, dtype=dtype
#     532         )
#
# /usr/local/Cellar/jupyterlab/3.0.9/libexec/lib/python3.9/site-packages/pandas/core/internals/construction.py in _list_of_dict_to_arrays(data, columns, coerce_float, dtype)
#     641         gen = (list(x.keys()) for x in data)
#     642         sort = not any(isinstance(d, dict) for d in data)
# --> 643         columns = lib.fast_unique_multiple_list_gen(gen, sort=sort)
#     644
#     645     # assure that they are of the base dict class and not of derived
#
# pandas/_libs/lib.pyx in pandas._libs.lib.fast_unique_multiple_list_gen()
#
# /usr/local/Cellar/jupyterlab/3.0.9/libexec/lib/python3.9/site-packages/pandas/core/internals/construction.py in <genexpr>(.0)
#     639     """
#     640     if columns is None:
# --> 641         gen = (list(x.keys()) for x in data)
#     642         sort = not any(isinstance(d, dict) for d in data)
#     643         columns = lib.fast_unique_multiple_list_gen(gen, sort=sort)
#
# AttributeError: 'NoneType' object has no attribute 'keys'

# %%
# 1.Fuction.
def check():
        selected_song = input(str('Tell me a song : ')).title()
        if selected_song in songs['title'].values:  
            recomendation = songs.sample()
            print('It is in the list, probaly you will like',recomendation['title'].values[0], 'from',recomendation['artist'].values[0])
        else: 
            link = input("Right now it is not a hot song, so tell my the link of a playlist,\n" 
                         "I'll recomend you a song based on this playlist,\n"
                         "it will take me a few moments : ")
            code = re.findall('\w{20,25}', str(link))
            playlist = sp.user_playlist_tracks("spotify", code[0])
            playlist_more_song_features(playlist)
            uri = sp.search(q=selected_song)['tracks']['items'][0]['uri']
            user_song_feat = sp.audio_features(uri)
            user_song_feat = pd.DataFrame(user_song_feat).drop(['id','uri','track_href','analysis_url','type'],axis=1)
            user_song_feat_sca = scale.transform(user_song_feat)
            user_clus = kmeans.predict(user_song_feat_sca)  
            
            recomendation = (song_clusters[song_clusters['cluster'] == user_clus[0]]).sample()
            
            print('Probably you will like ',
                  (recomendation['song'].values)[0],
                 'from ', (recomendation['artists'].values)[0],"enjoy it.")

# %% [markdown]
# ### 1.Getting all libraries.

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import random
import re
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %% [markdown]
# ### 2. Web scraping to have a data set of top songs.

# %%
url = 'https://www.billboard.com/charts/hot-100'
response = requests.get(url)
response.status_code
soup = BeautifulSoup(response.content, "html.parser")

# To generate the data frame of all top songs.
num_itr = len(soup.select('span.chart-element__information > span.chart-element__information__song.text--truncate.color--primary'))

rank = []
title = []
art = []

for song in range(num_itr):
    title.append(soup.select('span.chart-element__information__song')[song].get_text())
    art.append(soup.select('span.chart-element__information__artist')[song].get_text())
    rank.append(soup.select('span.chart-element__rank__number')[song].get_text())
songs = pd.DataFrame({"ranking":rank, "title":title, "artist":art})

# %% [markdown]
# ### 3. Create a collection of songs with their audio features, depending on a link to give the recomendation.

# %%
secrets_file = open("../../spotify_user.txt","r")
string = secrets_file.read()
string.split('\n')
secrets_dict={}
for line in string.split('\n'):
  secrets_dict[line.split(':')[0]]=line.split(':')[1]

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['client_id'],
                                                           client_secret=secrets_dict['client_secret']))

# %%
def playlist_more_song_features(playlist):
    global scale
    global kmeans
    global song_clusters
    
    songs = get_name_artists_from_playlist(playlist) 

    # In order to get all the singers in a list.
    singers = []
    for i in range(len(songs)):             
        singers.append(songs[i][1])

    singers = list(dict.fromkeys(singers))  #To drop duplicates singers

    # Itereting with the previous fuction, we have names of more songs in a list
    more_songs = []   
    for i in range(len(singers)):  
        more_songs.append(get_artist_tracks(singers[i]))

    more_songs = flatten(more_songs)  # To have it in a singel list

    songs_names = []
    artists_names = []
    uris = []

    # To have the songs and artists names and features
    for track in more_songs:
        songs_names.append(track['name'])
        artists_names.append(track['artists'][0]['name'])

    i = 0
    chunk_of_100_uris = []
    for track in more_songs:
        if i < 100:
            chunk_of_100_uris.append(sp.audio_features(track['uri']))
            i = i+1
        else:
            uris.append(chunk_of_100_uris)
            i = 0
            chunk_of_100_uris = []
            chunk_of_100_uris.append(sp.audio_features(track['uri']))
            i = i+1       
    uris.append(chunk_of_100_uris)   

    uris = flatten(flatten(uris))  # To have a unique list

    #Creating the data Frame
    S = pd.DataFrame(songs_names)
    A = pd.DataFrame(artists_names)
    U = pd.DataFrame(uris)

    S.columns = ['song']
    A.columns = ['artists']

    SAU = pd.concat([S,A,U],axis=1)
    SAU = SAU.drop(['id','uri','track_href','analysis_url','type'],axis=1)


    #Spliting the data frame
    SAU_name = SAU[['song','artists']]
    SAU_features = SAU.drop(['song','artists'],axis=1)

    # Normalizing it.
    scale = StandardScaler()
    X_prep = scale.fit_transform(SAU_features)

    # The prediction model.
    kmeans = KMeans(n_clusters=12, random_state=1234)
    kmeans.fit(X_prep)

    # Predicting / assigning the clusters:
    clusters = kmeans.predict(X_prep)

    #Finall data frame
    clusters = pd.DataFrame(clusters, columns = ['cluster'])
    SAU_features_stand = pd.DataFrame(X_prep,columns = SAU_features.columns)
    song_clusters = pd.concat([clusters,SAU_name,SAU_features_stand],axis=1)
    song_clusters = song_clusters.drop_duplicates(['song','artists'])

# %% [markdown]
# ### 4. Fuctions

# %%
def get_name_artists_from_track(track):
    return [(track["name"],track['artists'][0]['name'])]

def get_name_artist_from_playlist_item(playlist_item):
      return get_name_artists_from_track(playlist_item['track'])
    
def flatten(input_list):
      return [item for sublist in input_list for item in sublist]
    
def get_name_artists_from_playlist(input_playlist):
      return flatten(list(map(get_name_artist_from_playlist_item,input_playlist["items"])))
    
# Defining a fuction to be able to get 950 songs of each singer in the previous list.
def get_artist_tracks(artist):  
    results = sp.search(q=artist,limit=50)
    tracks = results['tracks']['items']
    i=0
    while ((results['tracks']['next']!=None)) & (i<19):
        i = i+1
        results = sp.next(results['tracks'])
        tracks = tracks + results['tracks']['items']
    return tracks
